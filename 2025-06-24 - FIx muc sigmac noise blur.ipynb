# %%
from pylab import *

# %%
from deficit_defs_2025_02_25 import *
# Out:
# Splikes version  0.1.5
# Plasticnet version  0.1.14
# macOS-15.5-arm64-arm-64bit
# Base Image File: asdf/bbsk081604_all_scale2.asdf

# %% [markdown]
# doing eta=2e-6 and time = 32 days

# %%
base_sim_dir=f"sims-2025-06-23 mu_c sigma_c blur"
if not os.path.exists(base_sim_dir):
    print("new")
    os.mkdir(base_sim_dir)
print(base_sim_dir)
# Out:
# sims-2025-06-23 mu_c sigma_c blur

# %%
def default_post(number_of_neurons):
    post=pn.neurons.linear_neuron(number_of_neurons)
    post+=pn.neurons.process.sigmoid(0,50)
    return post

def default_bcm(pre,post,orthogonalization=True):
    c=pn.connections.BCM(pre,post,[-.01,.01],[.1,.2])
    
    if orthogonalization:
        c+=pn.connections.process.orthogonalization(10*minute)

    c.eta=2e-6
    c.tau=15*pn.minute   

    return c

# %% [markdown]
# ## Deficit
# ![image.png](attachment:9bb2160e-35ad-40c3-99dc-d3991023d6cc.png)
#
# ## Optical Correction
# ![image.png](attachment:6a51ae86-282a-4e70-9003-f8ff5b67ef68.png)

# %%
def deficit(blur=[2.5,-1],noise=[0.1,0.1],rf_size=19,
            eta=2e-6,
           number_of_neurons=10,
            mu_c=0,sigma_c=0,    
            mu_r=0,sigma_r=0,
           total_time=8*day,
           save_interval=1*hour):

    
    
    im=[]
    for b in blur:
        if b<0:
            im+=[pi5.filtered_images(base_image_file,
                                    {'type':'norm'},
                                    {'type':'dog','sd1':1,'sd2':3},   
                                    verbose=False,
                                    )
                ]
        else:
            im+=[pi5.filtered_images(base_image_file,
                                    {'type':'blur','size':b},
                                    {'type':'norm'},
                                    {'type':'dog','sd1':1,'sd2':3},   
                                    verbose=False,
                                    )
                ]
    pre1=pn.neurons.natural_images_with_jitter(im[0],
                                   rf_size=rf_size,
                                                sigma_r=0,
                                                sigma_c=0,
                                       verbose=False)

    pre2=pn.neurons.natural_images_with_jitter(im[1],rf_size=rf_size,
                                other_channel=pre1,
                                    mu_r=mu_r,mu_c=mu_c,
                                    sigma_r=sigma_r,sigma_c=sigma_c,
                                verbose=False)

    pre1+=pn.neurons.process.add_noise_normal(0,noise[0])

    sigma=noise
    pre2+=pn.neurons.process.add_noise_normal(0,noise[1])

    pre=pre1+pre2

    post=default_post(number_of_neurons)
    c=default_bcm(pre,post)
    c.eta=eta

    sim=pn.simulation(total_time)
    sim.dt=200*ms

    sim.monitor(post,['output'],save_interval)
    sim.monitor(c,['weights','theta'],save_interval)

    sim+=pn.grating_response(print_time=False,
                        k_mat=linspace(1,20,40)/19.0*pi,
                            )

    return sim,[pre,post],[c]


@ray.remote
def run_one_deficit(params,run=True,overwrite=False):
    import plasticnet as pn
    noise,blur,mu_c,mu_r,sigma_c,sigma_r,number_of_neurons,total_time,sfname=(
                                params.noise,
                                params.blur,
                                params.mu_c,
                                params.mu_r,
                                params.sigma_c,
                                params.sigma_r,
                                params.number_of_neurons,
                                params.total_time,
                                params.sfname)
    
    if not overwrite and os.path.exists(sfname):
        return sfname
    
    seq=pn.Sequence()
    # deliberately use a standard deficit, with it's own eta and noise
    seq+=deficit(number_of_neurons=params.number_of_neurons,
                 noise=noise,blur=blur,
                 total_time=total_time,
                 mu_c=mu_c,sigma_c=sigma_c,
                mu_r=mu_r,sigma_r=sigma_r,) 


    if run:
        seq.run(display_hash=False)
        pn.save(sfname,seq) 
    
    return sfname

# %%
def fix(noise=[0.1,0.1],rf_size=19,
           number_of_neurons=10,
           total_time=8*day,
           save_interval=1*hour,
            mu_c=0,sigma_c=0,    
            mu_r=0,sigma_r=0,        
           eta=2e-6):
    
    
    im=[]
    im+=[pi5.filtered_images(base_image_file,
                        {'type':'norm'},
                        {'type':'dog','sd1':1,'sd2':3},   
                        verbose=False,
                        )
        ]
    im+=[pi5.filtered_images(base_image_file,
                        {'type':'norm'},
                        {'type':'dog','sd1':1,'sd2':3},
                        verbose=False,
                        )
        ]
                     
    
    
    pre1=pn.neurons.natural_images_with_jitter(im[0],
                                        rf_size=rf_size,
                                        sigma_r=0,
                                        sigma_c=0,
                                        verbose=False)

    pre2=pn.neurons.natural_images_with_jitter(im[1],
                                       rf_size=rf_size,
                                       other_channel=pre1,
                                       mu_r=mu_r,mu_c=mu_c,
                                       sigma_r=sigma_r,sigma_c=sigma_c,
                                       verbose=False)
    
    


    pre1+=pn.neurons.process.add_noise_normal(0,noise[0])
    pre2+=pn.neurons.process.add_noise_normal(0,noise[1])

    pre=pre1+pre2

    post=default_post(number_of_neurons)
    c=default_bcm(pre,post)
    c.eta=eta

    save_interval=save_interval

    sim=pn.simulation(total_time)

    sim.dt=200*ms

    sim.monitor(post,['output'],save_interval)
    sim.monitor(c,['weights','theta'],save_interval)

    sim+=pn.grating_response(print_time=False,
                        k_mat=linspace(1,20,40)/19.0*pi)

    return sim,[pre,post],[c]

@ray.remote
def run_one_continuous_fix(params,run=True,overwrite=False):
    import plasticnet as pn
    count,eta,noise,mu_c,mu_r,sigma_c,sigma_r,number_of_neurons,sfname=(
                                params.count,
                                params.eta,
                                params.noise,
                                params.mu_c,
                                params.mu_r,
                                params.sigma_c,
                                params.sigma_r,
                                params.number_of_neurons,
                                params.sfname)
    
    if not overwrite and os.path.exists(sfname):
        return sfname
    
    seq=pn.Sequence()
    # deliberately use a standard deficit, with it's own eta and noise
    seq+=deficit(number_of_neurons=params.number_of_neurons,
                 mu_c=mu_c,sigma_c=sigma_c,
                mu_r=mu_r,sigma_r=sigma_r,) 

    seq+=fix(total_time=100*hour,
             save_interval=20*minute,number_of_neurons=params.number_of_neurons,
             eta=eta,noise=noise,mu_c=mu_c,sigma_c=sigma_c,
             mu_r=mu_r,sigma_r=sigma_r)

    if run:
        seq.run(display_hash=False)
        pn.save(sfname,seq) 
    
    return sfname

# %%
number_of_neurons=20
number_of_processes=8
ray.init(num_cpus=number_of_processes)
# Out:
# 2025-06-23 16:37:30,476	INFO worker.py:1888 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.12.6', ray_version='2.46.0', ray_commit='c3dd2ca0c2a24ddf327a213d2e936bd4eaa4ca0a')
# (pid=80179) Splikes version  0.1.5
# (pid=80179) Plasticnet version  0.1.14
# (run_one_deficit pid=80179) [
# (pid=80172) Splikes version  0.1.5
# (pid=80176) Plasticnet version  0.1.14
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 2.29 s
# (run_one_deficit pid=80178) [ [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (pid=80178) Splikes version  0.1.5 [repeated 6x across cluster]
# (pid=80178) Plasticnet version  0.1.14 [repeated 6x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 8.04 s [repeated 7x across cluster]
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80177) [
# (run_one_deficit pid=80177) .] Sequence Time Elapsed...6 m, 4.55 s
# (run_one_deficit pid=80179) [ [repeated 6x across cluster]
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 5.06 s
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 6.87 s [repeated 6x across cluster]
# (run_one_deficit pid=80177) [
# (run_one_deficit pid=80179) [ [repeated 7x across cluster]
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 3.69 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 5.55 s [repeated 6x across cluster]
# (run_one_deficit pid=80176) [ [repeated 6x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 6.00 s
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 3.08 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 4.05 s [repeated 5x across cluster]
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 5.79 s [repeated 2x across cluster]
# (run_one_deficit pid=80175) [ [repeated 5x across cluster]
# (run_one_deficit pid=80179) [ [repeated 2x across cluster]
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 4.20 s
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 5.34 s [repeated 4x across cluster]
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 6.00 s [repeated 2x across cluster]
# (run_one_deficit pid=80173) [ [repeated 4x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 7.60 s
# (run_one_deficit pid=80179) [ [repeated 3x across cluster]
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 3.87 s
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 4.11 s [repeated 4x across cluster]
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 5.40 s
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 5.94 s
# (run_one_deficit pid=80173) [ [repeated 4x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 6.62 s
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 2.42 s
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 3.77 s [repeated 4x across cluster]
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 5.90 s
# (run_one_deficit pid=80173) [ [repeated 4x across cluster]
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 6.26 s
# (run_one_deficit pid=80175) [
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 7.76 s
# (run_one_deficit pid=80176) [
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 2.44 s
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 2.77 s [repeated 4x across cluster]
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 3.49 s
# (run_one_deficit pid=80173) [ [repeated 4x across cluster]
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 3.69 s
# (run_one_deficit pid=80175) [
# (run_one_deficit pid=80176) [
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 6.68 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 1.54 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 2.32 s [repeated 2x across cluster]
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 2.89 s [repeated 2x across cluster]
# (run_one_deficit pid=80178) [ [repeated 2x across cluster]
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 2.65 s
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 3.53 s
# (run_one_deficit pid=80173) [ [repeated 2x across cluster]
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 4.85 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 1.23 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 2.98 s [repeated 2x across cluster]
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 2.59 s [repeated 3x across cluster]
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 2.48 s
# (run_one_deficit pid=80173) [ [repeated 2x across cluster]
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 5.83 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 2.39 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 2.67 s [repeated 2x across cluster]
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 2.50 s [repeated 3x across cluster]
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 3.88 s
# (run_one_deficit pid=80173) [ [repeated 2x across cluster]
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 6.15 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 2.20 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 1.50 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 4.26 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 3.02 s [repeated 3x across cluster]
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 4.05 s
# (run_one_deficit pid=80177) [ [repeated 2x across cluster]
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 7.97 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 0.57 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 3.16 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 3.33 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 3.39 s [repeated 3x across cluster]
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80175) [ [repeated 3x across cluster]
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 3.92 s
# (run_one_deficit pid=80176) [
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 5.46 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 6.97 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 7.54 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 8.25 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 8.30 s [repeated 3x across cluster]
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 7.92 s
# (run_one_deficit pid=80173) [ [repeated 2x across cluster]
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 6.03 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 4.49 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 2.99 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 4.96 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 6.04 s [repeated 2x across cluster]
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 4.80 s
# (run_one_deficit pid=80173) [ [repeated 2x across cluster]
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 5.20 s
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 8.98 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 3.81 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 4.14 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 5.32 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 5.10 s [repeated 2x across cluster]
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 5.30 s
# (run_one_deficit pid=80173) [ [repeated 2x across cluster]
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 5.51 s
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 9.75 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 4.81 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 5.30 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 7.29 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 7.57 s [repeated 3x across cluster]
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 6.17 s
# (run_one_deficit pid=80173) [ [repeated 2x across cluster]
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 7.92 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 4.11 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 4.09 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 5.33 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 4.54 s [repeated 3x across cluster]
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 5.67 s
# (run_one_deficit pid=80173) [ [repeated 2x across cluster]
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 9.58 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 5.12 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 4.44 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 5.05 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 6.11 s
# (run_one_deficit pid=80177) .] Sequence Time Elapsed...6 m, 6.96 s
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 6.24 s
# (run_one_deficit pid=80177) [
# (run_one_deficit pid=80173) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 6.92 s
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 7.51 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 2.62 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 2.19 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 4.57 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 4.20 s
# (run_one_deficit pid=80177) .] Sequence Time Elapsed...6 m, 4.48 s
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 5.93 s
# (run_one_deficit pid=80173) [
# (run_one_deficit pid=80177) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 4.38 s
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 5.89 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 3.14 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 2.65 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 4.80 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80177) .] Sequence Time Elapsed...6 m, 5.18 s
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 5.61 s
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 5.15 s
# (run_one_deficit pid=80177) [
# (run_one_deficit pid=80173) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 4.80 s
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 7.06 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 1.67 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 3.77 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 3.89 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 4.07 s
# (run_one_deficit pid=80177) .] Sequence Time Elapsed...6 m, 4.43 s
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 3.39 s
# (run_one_deficit pid=80173) [
# (run_one_deficit pid=80177) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 3.15 s
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 6.18 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 4.06 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 3.84 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 5.10 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 5.60 s
# (run_one_deficit pid=80177) .] Sequence Time Elapsed...6 m, 6.80 s
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 6.65 s
# (run_one_deficit pid=80173) [
# (run_one_deficit pid=80177) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 6.53 s
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 9.32 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 2.95 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 2.58 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 4.63 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 4.18 s
# (run_one_deficit pid=80177) .] Sequence Time Elapsed...6 m, 4.80 s
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 4.18 s
# (run_one_deficit pid=80173) [
# (run_one_deficit pid=80177) [
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 4.39 s
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 7.81 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 4.35 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 3.68 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 4.83 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 5.28 s
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80177) .] Sequence Time Elapsed...6 m, 5.36 s
# (run_one_deficit pid=80173) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 4.08 s
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 4.81 s
# (run_one_deficit pid=80177) [
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 8.24 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 3.98 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 4.91 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 5.22 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 5.90 s
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 5.72 s
# (run_one_deficit pid=80173) [
# (run_one_deficit pid=80177) .] Sequence Time Elapsed...6 m, 6.56 s
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 5.29 s
# (run_one_deficit pid=80175) [
# (run_one_deficit pid=80176) [ [repeated 2x across cluster]
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 7.38 s
# (run_one_deficit pid=80179) [
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 3.00 s
# (run_one_deficit pid=80172) [
# (run_one_deficit pid=80174) .] Sequence Time Elapsed...6 m, 4.14 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 4.49 s
# (run_one_deficit pid=80174) [
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 4.94 s
# (run_one_deficit pid=80178) [
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 4.62 s
# (run_one_deficit pid=80173) [
# (run_one_deficit pid=80177) .] Sequence Time Elapsed...6 m, 4.34 s
# (run_one_deficit pid=80176) .] Sequence Time Elapsed...6 m, 4.20 s
# (run_one_deficit pid=80175) [
# (run_one_deficit pid=80179) .] Sequence Time Elapsed...6 m, 5.33 s
# (run_one_deficit pid=80172) .] Sequence Time Elapsed...6 m, 2.94 s
# (run_one_deficit pid=80178) .] Sequence Time Elapsed...6 m, 3.37 s [repeated 2x across cluster]
# (run_one_deficit pid=80173) .] Sequence Time Elapsed...6 m, 3.78 s
# (run_one_deficit pid=80175) .] Sequence Time Elapsed...6 m, 3.75 s
# (raylet) [2025-06-23 19:36:14,659 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.899 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:36:24,749 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.898 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:36:34,838 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 182.898 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:36:44,925 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.897 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:36:55,010 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 178.896 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:37:05,099 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 176.895 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:37:15,186 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 174.894 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:37:25,280 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 172.894 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:37:35,371 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 183.894 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:51:15,289 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.091 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:51:25,381 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.062 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:51:35,467 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.018 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:51:45,555 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.964 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:51:55,640 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.005 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:52:05,726 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.02 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:52:15,813 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.962 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:52:25,908 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.963 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:52:35,997 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.974 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:52:46,091 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.023 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:52:56,185 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.041 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:53:06,278 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.035 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:53:16,369 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.027 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:53:26,459 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.999 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:53:36,552 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.998 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:53:46,647 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.998 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:53:56,738 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.995 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:54:06,833 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.995 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:54:16,926 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.995 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:54:27,017 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.995 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:54:37,114 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.995 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:54:47,206 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.023 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:54:57,296 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.067 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:55:07,387 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 186.067 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:56:37,503 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.671 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:56:47,598 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.418 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:56:57,682 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.417 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:57:07,776 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.35 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:57:17,869 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.35 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:57:27,963 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.35 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:57:38,056 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.35 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:57:48,144 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.35 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:57:58,233 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 185.348 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:58:08,325 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.533 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:58:18,422 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.687 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:58:28,512 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.687 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:58:38,602 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.687 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:58:48,686 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.687 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:58:58,778 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.686 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:59:08,873 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.686 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:59:18,963 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.686 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:59:29,048 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.686 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:59:39,139 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.686 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:59:49,237 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.686 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 19:59:59,335 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.686 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:00:09,429 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.685 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:00:19,522 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.683 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:00:29,617 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.681 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:00:39,714 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.67 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:00:49,805 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.669 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:00:59,895 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.669 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:01:09,985 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.669 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:01:20,080 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.667 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:01:30,170 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.667 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:01:40,262 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.667 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:01:50,352 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.667 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:02:00,447 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.667 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:02:10,543 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.667 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:02:20,635 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.667 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:02:30,727 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.667 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:02:40,826 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.667 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:02:50,919 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.666 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:03:01,013 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.666 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:03:11,109 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.666 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:03:21,200 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.674 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:03:31,293 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.674 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:03:41,385 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.664 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:03:51,464 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.28 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:04:01,541 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.285 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:04:11,629 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.285 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:04:21,635 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.277 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:04:31,731 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.277 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:04:41,821 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.277 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:04:51,916 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:05:02,013 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:05:12,112 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:05:22,203 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.275 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:05:32,296 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.28 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:05:42,390 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.28 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:05:52,489 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.278 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:06:02,583 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.278 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:06:12,679 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.278 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:06:22,773 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:06:32,873 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:06:42,972 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:06:53,068 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:07:03,157 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:07:13,253 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:07:23,349 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:07:33,442 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:07:43,535 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:07:53,628 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:08:03,717 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:08:13,815 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:08:23,906 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:08:33,998 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.276 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:08:44,095 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.28 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:08:54,185 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.279 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:09:04,274 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.279 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:09:14,367 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.278 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:09:24,400 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.281 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:09:34,447 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.297 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:09:44,509 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.294 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:09:54,558 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.287 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:10:04,626 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.287 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-23 20:10:14,672 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 184.286 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# ...
# (raylet) [2025-06-24 11:44:47,090 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.41 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:44:57,189 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.409 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:45:07,284 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.408 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:45:17,376 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.408 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:45:27,471 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.408 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:45:37,566 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.407 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:45:47,655 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.407 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:45:57,747 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.407 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:46:07,843 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.406 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:46:17,938 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.406 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:46:28,031 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.406 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:46:38,124 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.405 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:46:48,216 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.405 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:46:58,314 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.405 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:47:08,407 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.402 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:47:18,503 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.402 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:47:28,596 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.402 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:47:38,690 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.402 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:47:48,788 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.402 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:47:58,884 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.402 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:48:08,977 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.4 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:48:19,069 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.4 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:48:29,161 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.4 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:48:39,253 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.399 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:48:49,342 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.398 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:48:59,433 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.401 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:49:09,522 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.4 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:49:19,617 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.403 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:49:29,715 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.403 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:49:39,813 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.402 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:49:49,904 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.402 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:50:00,000 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.402 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:50:10,095 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.401 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:50:20,192 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.4 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:50:30,290 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.402 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:50:40,374 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.405 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:50:50,470 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.405 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:51:00,567 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.405 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:51:10,577 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.404 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:51:20,669 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.404 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:51:30,758 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.421 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:51:40,766 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.426 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:51:50,857 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.419 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:52:00,956 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.41 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:52:11,046 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.381 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:52:21,139 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.38 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:52:31,233 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.38 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:52:41,321 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.379 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:52:51,417 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.379 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:53:01,418 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.379 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:53:11,513 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.378 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:53:21,611 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.378 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:53:31,711 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.377 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:53:41,806 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.377 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:53:51,901 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.377 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:54:01,908 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.377 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:54:12,009 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.377 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:54:22,106 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.377 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:54:32,203 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.377 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:54:42,293 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.379 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:54:52,385 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.38 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.
# (raylet) [2025-06-24 11:55:02,478 E 80168 5939001] (raylet) file_system_monitor.cc:116: /tmp/ray/session_2025-06-23_16-37-29_868306_80121 is over 95% full, available space: 180.379 GB; capacity: 3721.87 GB. Object creation will fail if spilling is required.

# %%
blur_mat=linspace(0,8,17)
blur_mat
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ,
#        6.5, 7. , 7.5, 8. ])

# %%
mu_c_mat=linspace(0,20,9)
mu_c_mat
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. ])

# %%
mu_c_mat=linspace(0,30,13)
mu_c_mat
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5, 25. ,
#        27.5, 30. ])

# %%
func=run_one_deficit
count=0
open_eye_noise=0.1
sigma_c=2.0
mu_r=0.0
sigma_r=0.0

all_params=[]
for mu_count,mu_c in enumerate(mu_c_mat):
    for blur_count,blur in enumerate(blur_mat):
        sfname=f'{base_sim_dir}/deficit {number_of_neurons} neurons noise {open_eye_noise:.1f} blur {blur:.1f} mu_c {mu_c:.1f} sigma_c {sigma_c:.1f}.asdf'

        p=Struct()
        p.number_of_neurons=number_of_neurons
        p.sfname=sfname
        p.mu_c=mu_c
        p.sigma_c=sigma_c
        p.mu_r=mu_r
        p.sigma_r=sigma_r
        p.blur=[blur,-1]

        p.total_time=16*day*2
        p.noise=(open_eye_noise,open_eye_noise)
        all_params+=[p]

        
for a in all_params[:5]:
    print(a)
print("[....]")
for a in all_params[-5:]:
    print(a)

print(len(all_params))
# Out:
# {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 0.0 sigma_c 2.0.asdf', 'mu_c': 0.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [0.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}
# {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 0.0 sigma_c 2.0.asdf', 'mu_c': 0.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [0.5, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}
# {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 0.0 sigma_c 2.0.asdf', 'mu_c': 0.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [1.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}
# {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 0.0 sigma_c 2.0.asdf', 'mu_c': 0.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [1.5, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}
# {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 0.0 sigma_c 2.0.asdf', 'mu_c': 0.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [2.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}
# [....]
# {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 30.0 sigma_c 2.0.asdf', 'mu_c': 30.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [6.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}
# {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 30.0 sigma_c 2.0.asdf', 'mu_c': 30.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [6.5, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}
# {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 30.0 sigma_c 2.0.asdf', 'mu_c': 30.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [7.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}
# {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 30.0 sigma_c 2.0.asdf', 'mu_c': 30.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [7.5, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}
# {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 30.0 sigma_c 2.0.asdf', 'mu_c': 30.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [8.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}
# 221

# %%
### premake the images
for params in tqdm(all_params):
    result=func.remote(params,run=False,overwrite=True)
    sfname=ray.get(result)
    print(sfname)
# Out:
#   0%|          | 0/221 [00:00<?, ?it/s]
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 0.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 2.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 5.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 7.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 10.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 12.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 15.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 17.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 20.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 22.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 25.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 27.5 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.5 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.0 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 3.5 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.0 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 4.5 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.0 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 5.5 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 30.0 sigma_c 2.0.asdf
# sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 30.0 sigma_c 2.0.asdf

# %%
do_params=make_do_params(all_params,verbose=True)
# Out:
# 221 sims
# [{'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 0.0 sigma_c 2.0.asdf', 'mu_c': 0.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [0.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}, {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 0.0 sigma_c 2.0.asdf', 'mu_c': 0.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [0.5, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}, {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 0.0 sigma_c 2.0.asdf', 'mu_c': 0.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [1.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}, {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.5 mu_c 0.0 sigma_c 2.0.asdf', 'mu_c': 0.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [1.5, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}, {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 2.0 mu_c 0.0 sigma_c 2.0.asdf', 'mu_c': 0.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [2.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}] ... [{'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.0 mu_c 30.0 sigma_c 2.0.asdf', 'mu_c': 30.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [6.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}, {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 6.5 mu_c 30.0 sigma_c 2.0.asdf', 'mu_c': 30.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [6.5, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}, {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.0 mu_c 30.0 sigma_c 2.0.asdf', 'mu_c': 30.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [7.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}, {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 7.5 mu_c 30.0 sigma_c 2.0.asdf', 'mu_c': 30.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [7.5, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}, {'number_of_neurons': 20, 'sfname': 'sims-2025-06-23 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 8.0 mu_c 30.0 sigma_c 2.0.asdf', 'mu_c': 30.0, 'sigma_c': 2.0, 'mu_r': 0.0, 'sigma_r': 0.0, 'blur': [8.0, -1], 'total_time': 2764800, 'noise': (0.1, 0.1)}]

# %%
results = [func.remote(p) for p in do_params]
sfnames=ray.get(results)

# %%
RR={}
for params in tqdm(all_params):
    RR[params.sfname]=Results(params.sfname)
# Out:
#   0%|          | 0/221 [00:00<?, ?it/s]

# %%
subResults={}
for params in tqdm(all_params):
    sfname=params.sfname
    R=RR[sfname]
    
    subR=Struct()
    subR.t=R.t/day
    t=subR.t
    
    subR.y=R.y
    subR.θ=R.θ

    idx1=R.sequence_index[0][1]
    
    subR.ODI=R.ODI
    subR.ORI=R.ORI
    subR.theta_mat=R.theta_mat
    subR.k_mat=R.k_mat
    subR.SF_Var=R.SF_Var
    subR.max_SF=R.max_SF
    subR.sfname=params.sfname
    subR.params=params
    subR.sequence_index=R.sequence_index
    subR.idx=[0]+[_[-1] for _ in R.sequence_index]
    subR.W=R.W[subR.idx,::]
    subR.ODI1=R.ODI[idx1,:]
    
    subResults[params.sfname]=subR


savevars(f'{base_sim_dir}/deficit_results.asdf',
         'subResults','mu_c_mat','blur_mat',
          )
# Out:
#   0%|          | 0/221 [00:00<?, ?it/s]
# Saving sims-2025-06-23 mu_c sigma_c blur/deficit_results.asdf...done.

# %%
R.sequence_index
# Out:
# [(0, 768)]

# %%
count=0
for mu_count,mu_c in tqdm(enumerate(mu_c_mat)):
    s=Storage()
    for blur_count,blur in enumerate(blur_mat):
        params=all_params[count]
        count+=1
        R=RR[params.sfname]
        blur=params.blur[0]
        μ1,μ2=R.μσ[0][0]
        σ1,σ2=R.μσ[1][0]

        s+=blur,μ1,μ2,σ1,σ2
    
    
    blur,μ1,μ2,σ1,σ2=s.arrays()
    
    figure()
    errorbar(blur,μ1,yerr=2*σ1,marker='o',elinewidth=1,label='Deprived')
    errorbar(blur,μ2,yerr=2*σ2,marker='s',elinewidth=1,label='Normal')
    xlabel('Blur Size [pixels]')
    ylabel('Maximum Response')
    title(f'μ_c={mu_c},σ_c={sigma_c}')
    legend()
# Out:
# 0it [00:00, ?it/s]

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = mpl.colors.LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

Blues2 = truncate_colormap(cm.Blues, 0.3, 1.0).reversed()
Oranges2 = truncate_colormap(cm.Oranges, 0.3, 1.0).reversed()

count=0
v=np.flip(linspace(0.3,1,len(mu_c_mat)))

for mu_count,mu_c in enumerate(mu_c_mat):
    s=Storage()
    for blur_count,blur in enumerate(blur_mat):


            
        params=all_params[count]
        count+=1
        R=RR[params.sfname]
        blur=params.blur[0]
        μ1,μ2=R.μσ[0][0]
        σ1,σ2=R.μσ[1][0]

        if blur==0.5:  # one weird point which does not need to be explored right now
            continue

        
        s+=blur,μ1,μ2,σ1,σ2
    
    
    blur,μ1,μ2,σ1,σ2=s.arrays()
    
    if mu_count==0:
        errorbar(blur,μ1,yerr=2*σ1,marker='o',elinewidth=1,label=f'Deprived',color=cm.Oranges(v[mu_count]))
        errorbar(blur,μ2,yerr=2*σ2,marker='s',elinewidth=1,label=f'Normal',color=cm.Blues(v[mu_count]))
    else:
        errorbar(blur,μ1,yerr=2*σ1,marker='o',elinewidth=1,color=cm.Oranges(v[mu_count]))
        errorbar(blur,μ2,yerr=2*σ2,marker='s',elinewidth=1,color=cm.Blues(v[mu_count]))
    xlabel('Blur Size [pixels]')
    ylabel('Maximum Response')

legend(loc='upper left')

divider = make_axes_locatable(plt.gca())
ax_cb = divider.new_horizontal(size="5%", pad=0.05)   
ax_cb.grid(False)
ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
ax_cb2.grid(False)
cb1 = mpl.colorbar.ColorbarBase(ax_cb, cmap=Blues2,norm=mpl.colors.Normalize(vmin=mu_c_mat[0], vmax=mu_c_mat[-1]),orientation='vertical')
cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=Oranges2,norm=mpl.colors.Normalize(vmin=mu_c_mat[0], vmax=mu_c_mat[-1]),orientation='vertical')
plt.gcf().add_axes(ax_cb)
ax_cb.grid(True)
ax_cb.set_yticklabels([])
ax_cb2.grid(True)
title(r'$\mu_c$')
plt.gcf().add_axes(ax_cb2)
title(r'$\mu_c$')
# Out:
# Text(0.5, 1.0, '$\\mu_c$')

# %%
count=0
v=np.flip(linspace(0.3,1,len(mu_c_mat)))

for mu_count,mu_c in enumerate(mu_c_mat):
    s=Storage()
    for blur_count,blur in enumerate(blur_mat):
        params=all_params[count]
        count+=1
        R=RR[params.sfname]
        blur=params.blur[0]
        μ,σ=μσ(R.ODI[-1])

        if blur==0.5: # one weird point which does not need to be explored right now
            continue
        s+=blur,μ,σ
    
    
    blur,μ,σ=s.arrays()
    errorbar(blur,μ,yerr=2*σ,marker='o',elinewidth=1,color=cm.Oranges(v[mu_count]))    
    xlabel('Blur Size [pixels]')
    ylabel(r'$\longleftarrow$ Weak Eye              Strong Eye $\longrightarrow$'+"\nODI")
    ylim([-1,1])

divider = make_axes_locatable(plt.gca())
ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
ax_cb2.grid(False)
cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=Oranges2,norm=mpl.colors.Normalize(vmin=mu_c_mat[0], vmax=mu_c_mat[-1]),orientation='vertical')
ax_cb2.grid(True)
plt.gcf().add_axes(ax_cb2)
title(r'$\mu_c$')
# Out:
# Text(0.5, 1.0, '$\\mu_c$')

# %%
R.ODI[-1]
# Out:
# array([ 0.97724443, -0.99080577,  0.97429004, -0.97827704,  0.95951721,
#         0.98847696, -0.97414563,  0.99026919,  0.96741118,  0.9487334 ,
#        -0.95614516, -0.94905262,  0.96011261,  0.99083701,  0.91791564,
#         0.96745987,  0.95424804, -0.98850766,  0.97203878,  0.98226786])

# %%
count=0
v=np.flip(linspace(0.3,1,len(mu_c_mat)))

for mu_count,mu_c in enumerate(mu_c_mat):
    s=Storage()
    for blur_count,blur in enumerate(blur_mat):
        params=all_params[count]
        count+=1
        R=RR[params.sfname]
        blur=params.blur[0]    

        plot(blur*ones(params.number_of_neurons)+.2*mu_c/20,R.ODI[-1],'o',color=cm.Oranges(v[mu_count]))

        
xlabel('Blur Size [pixels]')
ylabel(r'$\longleftarrow$ Weak Eye              Strong Eye $\longrightarrow$'+"\nODI")
ylim([-1,1])

divider = make_axes_locatable(plt.gca())
ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
ax_cb2.grid(False)
cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=Oranges2,norm=mpl.colors.Normalize(vmin=mu_c_mat[0], vmax=mu_c_mat[-1]),orientation='vertical')
ax_cb2.grid(True)
plt.gcf().add_axes(ax_cb2)
title(r'$\mu_c$')
# Out:
# Text(0.5, 1.0, '$\\mu_c$')
