# %%
# %matplotlib inline
from pylab import *
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
from treatment_sims_2023_02_21 import *
# Out:
# Splikes version  0.1.2
# Plasticnet version  0.1.9
# macOS-10.16-x86_64-i386-64bit

# %%
base='sims/2023-03-27'
if not os.path.exists(base):
    print(f"mkdir {base}")
    os.mkdir(base)
    
old_base='sims/2023-03-01'

# %%
def mydisplay(t,sim,neurons,connections):
    global _fig
    from IPython.display import display, clear_output
    from pylab import figure,close,gcf,imshow,subplot,plot

    c=connections[0]

    weights=c.weights
    num_neurons=len(weights)
    rf_size=neurons[0][0].rf_size
    num_channels=len(neurons[0])

    W=weights.reshape((num_neurons,
                        num_channels,
                        rf_size,rf_size))

    vmin,vmax=W.min(),W.max()

    W=(W-vmin)/(vmax-vmin)

    blocks=[]
    for row in range(num_neurons):

        block_row=[]
        for col in range(num_channels):
            rf=W[row,col,:,:]
            block_row.append(rf)
            if col<num_channels-1:
                block_row.append(vmax*ones((rf_size,1)))
        blocks.append(block_row)

        if row<num_neurons-1:
            block_row=[]
            for col in range(num_channels):
                rf=W[row,col,:,:]
                block_row.append(vmax*ones((2,rf_size)))
                if col<num_channels-1:
                    block_row.append(vmax*ones((2,1)))
            blocks.append(block_row)


    

    im=np.block(blocks)

    t,θ=sim.monitors['theta'].arrays()

    try:
        clear_output(wait=True)
    
        _fig=figure(1)
        
        subplot(1,2,1)
        imshow(im,cmap=cm.gray)
        subplot(2,2,2)
        plot(t,θ)
        subplot(2,2,4)
        
        try:
            pp=sim.post_process[0]
            t=pp.t
            y=pn.utils.max_channel_response(pp.responses)
            y=y.transpose([2,1,0]) 
            plot(t,y[:,:,0],'m-')
            plot(t,y[:,:,1],'b-')        
        except AttributeError:
            pass
        
        _fig.canvas.draw_idle()
        display(_fig)
        close(_fig)
    except KeyboardInterrupt:
        close(_fig)
        raise

# %%
rf_size=19
eta=2e-6
blur=6
number_of_neurons=3
number_of_processes=4
mu_c=7.5
sigma_c=2
mu_r=0
sigma_r=0
noise=1


seq=pn.Sequence()

total_time=16*day
save_interval=1*hour

base_image_file='asdf/bbsk081604_all.asdf'
    
images=[]
dt=200*ms

for bv in [blur,-1]:
    if bv<=0:
        im=pi5.filtered_images(
                            base_image_file,
                            {'type':'dog','sd1':1,'sd2':3},
                            {'type':'norm'},
                            )
    else:
        im=pi5.filtered_images(
                                base_image_file,
                                {'type':'blur','size':bv},
                                {'type':'dog','sd1':1,'sd2':3},
                                {'type':'norm'},
                                )
    images.append(im)
    
    
dt=200*ms        
pre1=pn.neurons.natural_images_with_jitter(images[0],
                                            rf_size=rf_size,
                                            time_between_patterns=dt,
                                            sigma_r=1,
                                            sigma_c=1,
                                            verbose=False)

pre2=pn.neurons.natural_images_with_jitter(images[1],
                                            rf_size=rf_size,
                                            other_channel=pre1,
                                            time_between_patterns=dt,
                                            mu_r=mu_r,mu_c=mu_c,
                                            sigma_r=sigma_r,sigma_c=sigma_c,
                                            verbose=False)



sigma=noise
pre1+=pn.neurons.process.add_noise_normal(0,sigma)

sigma=noise
pre2+=pn.neurons.process.add_noise_normal(0,sigma)

pre=pre1+pre2

post=default_post(number_of_neurons)
c=default_bcm(pre,post)
c.eta=eta

sim=pn.simulation(total_time)
sim.dt=dt

sim.monitor(post,['output'],save_interval)
sim.monitor(c,['weights','theta'],save_interval)
sim+=pn.grating_response(print_time=False)



seq+=sim,[pre,post],[c]


# seq.run(display=mydisplay,display_hash=False,
#                time_between_display=save_interval)


# pn.save(sfname,seq)
# Out:
# Using cache_images/cache_images_33487c39ae14fd4b2e1147c1b93a3055.asdf from cache.Using cache_images/cache_images_c2e0829f3e61ca9a4b271b0f7c2ee1f1.asdf from cache.

# %% [markdown]
# ## Atropine

# %%
deficit_base_sim=sfname

noise=0.1
blur=10

seq=pn.Sequence()
seq+=treatment_jitter(blur=blur,
               noise=0.1,
               noise2=noise,  # treated (strong-eye) noise
               total_time=100*hour,number_of_neurons=number_of_neurons,
                mu_c=mu_c,sigma_c=sigma_c,
               eta=eta,
               save_interval=20*minute)

seq_load(seq,deficit_base_sim)    

seq.run(display=mydisplay,display_hash=False,
               time_between_display=save_interval)
# Out:
# Using cache_images/cache_images_c2e0829f3e61ca9a4b271b0f7c2ee1f1.asdf from cache.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/tmp/ipykernel_5885/1823912915.py in <module>
#       5
#       6 seq=pn.Sequence()
# ----> 7 seq+=treatment_jitter(blur=blur,
#       8                noise=0.1,
#       9                noise2=noise,  # treated (strong-eye) noise
#
# ~/Documents/Git/Amblyopia-Simulation/treatment_sims_2023_02_21.py in treatment_jitter(contrast, noise, noise2, rf_size, eta, f, mu_c, sigma_c, mu_r, sigma_r, number_of_neurons, total_time, save_interval, mask, blur)
#     257
#     258         if blur:
# --> 259             blur_fname=pi5.filtered_images(im,
#     260                                         {'type':'blur','size':blur},
#     261                                         {'type':'dog','sd1':1,'sd2':3},
#
# ~/Documents/Git/Amblyopia-Simulation/process_images_hdf5.py in filtered_images(fname, resolution, cache, verbose, base_directory, *args)
#     361
#     362             if T=='blur':
# --> 363                 image_data=make_blur(image_data,f['size'],
#     364                                     verbose=verbose)
#     365             elif T=="norm":
#
# ~/Documents/Git/Amblyopia-Simulation/filters.py in make_blur(var, sd, radius, verbose)
#     484     for count,im in enumerate(var['im']):
#     485         orig_size=im.shape
# --> 486         im2=dog_filter(im*im_scale_shift[0]+im_scale_shift[1],sd,0,2*radius+1,shape='same')
#     487         new_size=im2.shape
#     488
#
# ~/Documents/Git/Amblyopia-Simulation/filters.py in dog_filter(A, sd1, sd2, size, shape, surround_weight)
#      48     g=dog(sd1,sd2,size)
#      49
# ---> 50     B=sig.convolve2d(A,g,mode=shape)
#      51
#      52     return B
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/_signaltools.py in convolve2d(in1, in2, mode, boundary, fillvalue)
#    1720     val = _valfrommode(mode)
#    1721     bval = _bvalfromboundary(boundary)
# -> 1722     out = _sigtools._convolve2d(in1, in2, 1, val, bval, fillvalue)
#    1723     return out
#    1724
#
# KeyboardInterrupt:

# %%
pp=seq[0][0].post_process[0]
t=pp.t
y=pn.utils.max_channel_response(pp.responses)
y=y.transpose([2,1,0]) 
plot(t,y[:,:,0],'m-')
plot(t,y[:,:,1],'b-')
y.shape
# Out:
# (301, 3, 2)

# %% [markdown]
# ## Contrast w, w/o mask, etc...

# %%
deficit_base_sim=sfname

mask=0
f=10
contrast=.1



seq=pn.Sequence()

seq+=treatment_jitter(f=f,
               mask=mask,
               contrast=contrast,
               total_time=100*hour,
               eta=eta,
                mu_c=mu_c,sigma_c=sigma_c,
                      number_of_neurons=number_of_neurons,
               save_interval=20*minute)
seq_load(seq,deficit_base_sim)    

seq.run(display=mydisplay,display_hash=False,
               time_between_display=save_interval)
# Out:
# .] Sequence Time Elapsed...1 m, 13.48 s

# %%
pp=seq[0][0].post_process[0]
t=pp.t
y=pn.utils.max_channel_response(pp.responses)
y=y.transpose([2,1,0]) 
plot(t,y[:,:,0],'m-')
plot(t,y[:,:,1],'b-')
y.shape
# Out:
# (301, 3, 2)
