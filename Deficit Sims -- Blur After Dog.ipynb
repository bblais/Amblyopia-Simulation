# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
from deficit_defs import *
# Out:
# Splikes version  0.1.2
# Plasticnet version  0.1.6
# macOS-10.16-x86_64-i386-64bit
# Base Image File: asdf/bbsk081604_all_log2dog.asdf

# %%
_debug = False
if _debug:
    print("Debugging")

# %%
base='sims/2022-11-03b'
if not os.path.exists(base):
    print(f"mkdir {base}")
    os.mkdir(base)

# %%
rf_size=19
#eta_mat=linspace(1e-7,5e-6,11)
eta=2e-6
blur_mat=linspace(0,8,17)
print(blur_mat)
number_of_neurons=20
number_of_processes=4
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5.  5.5 6.  6.5 7.  7.5 8. ]

# %%
base_image_file='asdf/bbsk081604_all.asdf'
print("Base Image File:",base_image_file)

blur=2.5
Lfname=pi5.filtered_images(
                            base_image_file,
                            {'type':'log2dog','sd1':1,'sd2':3},
                            {'type':'blur','size':blur},
                            )
Rfname=pi5.filtered_images(
                            base_image_file,
                            {'type':'log2dog','sd1':1,'sd2':3},
                            )
# Out:
# Base Image File: asdf/bbsk081604_all.asdf
# Using cache_images/cache_images_9649b9bf37ed00c1393560ab844f71f7.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.

# %%
image_data=pi5.asdf_load_images(Lfname)
im=[arr.astype(float)*image_data['im_scale_shift'][0]+
        image_data['im_scale_shift'][1] for arr in image_data['im']]

del image_data
plt.figure(figsize=(16,8))
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(im[i],cmap=plt.cm.gray)
    plt.axis('off')

# %%
image_data=pi5.asdf_load_images(Rfname)
im=[arr.astype(float)*image_data['im_scale_shift'][0]+
        image_data['im_scale_shift'][1] for arr in image_data['im']]

del image_data
plt.figure(figsize=(16,8))
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(im[i],cmap=plt.cm.gray)
    plt.axis('off')

# %% [markdown]
# ## Premake the image files

# %%
blur_mat=linspace(0,8,17)
blur_mat
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ,
#        6.5, 7. , 7.5, 8. ])

# %%
blur_mat=linspace(0,16,33)
blur_mat
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,
#         5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. , 10.5,
#        11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. , 15.5, 16. ])

# %%
base_image_file='asdf/bbsk081604_all.asdf'
print("Base Image File:",base_image_file)

normal_image=pi5.filtered_images(
                                base_image_file,
                                {'type':'log2dog','sd1':1,'sd2':3},
                                )

for blur in blur_mat:

    Lfname=pi5.filtered_images(
                                base_image_file,
                                {'type':'log2dog','sd1':1,'sd2':3},
                                {'type':'blur','size':blur},
                                )
# Out:
#  [#############################100% (ETA: 0.0 s)#############################]
# Saving cache_images/cache_images_cafbf71ebd457bf75b7a2d280a152172.asdf...Resolution float64 -> uint16
# done.

# %%
def blur_deficit(blur=[2.5,-1],
            noise=[0.1,.1],
                 rf_size=19,eta=2e-6,
           number_of_neurons=10,
           total_time=8*day,
           save_interval=1*hour):

    
    if _debug:
        total_time=1*minute
        save_interval=1*second
        
    images=[]
    
    for bv in blur:
        if bv<=0:
            im=pi5.filtered_images(
                                base_image_file,
                                {'type':'log2dog','sd1':1,'sd2':3},
                                )
        else:
            im=pi5.filtered_images(
                                    base_image_file,
                                    {'type':'log2dog','sd1':1,'sd2':3},
                                    {'type':'blur','size':bv},
                                    )
        images.append(im)
        
    pre1=pn.neurons.natural_images(images[0],
                                   rf_size=rf_size,verbose=False)

    pre2=pn.neurons.natural_images(images[1],rf_size=rf_size,
                                other_channel=pre1,
                                verbose=False)

    sigma=noise
    pre1+=pn.neurons.process.add_noise_normal(0,sigma)

    sigma=noise
    pre2+=pn.neurons.process.add_noise_normal(0,sigma)

    pre=pre1+pre2

    post=default_post(number_of_neurons)
    c=default_bcm(pre,post)
    c.eta=eta

    sim=pn.simulation(total_time)
    sim.dt=200*ms

    sim.monitor(post,['output'],save_interval)
    sim.monitor(c,['weights','theta'],save_interval)

    sim+=pn.grating_response(print_time=False)

    return sim,[pre,post],[c]

# %%
def run_one_left_blur(params,overwrite=False):
    import plasticnet as pn
    count,eta,noise,blur,number_of_neurons,sfname=(params.count,params.eta,params.noise,params.blur,
                                        params.number_of_neurons,params.sfname)
    
    if not overwrite and os.path.exists(sfname):
        return sfname
    
    seq=pn.Sequence()

    t=16*day
    ts=1*hour

    # DEBUG
    if _debug:
        t=1*minute
        ts=1*second
    
    seq+=blur_deficit(blur=[blur,-1],total_time=t,
                 noise=noise,eta=eta,number_of_neurons=number_of_neurons,
               save_interval=ts)

    
    seq.run(display_hash=False)
    pn.save(sfname,seq) 
    
    return sfname

# %%
total_time=8*day
real_time=5*60+ 55

# %%
from collections import namedtuple
params = namedtuple('params', ['count', 'eta','noise','blur','number_of_neurons','sfname'])
all_params=[]
count=0
eta_count=0
eta=2e-6
noise_count=0
open_eye_noise=0.0

for blur_count,blur in enumerate(blur_mat):
    all_params.append(params(count=count,
                     eta=eta,
                         blur=blur,
                     noise=open_eye_noise,
                     number_of_neurons=number_of_neurons,
         sfname=f'{base}/deficit %d neurons logdog %d eta %d noise %d blur.asdf' % 
                                         (number_of_neurons,eta_count,noise_count,blur_count)))
        
for a in all_params[:10]:
    print(a)

print(len(all_params))

print(time2str(real_time*len(all_params)/number_of_processes))
# Out:
# params(count=0, eta=2e-06, noise=0.0, blur=0.0, number_of_neurons=20, sfname='sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 0 blur.asdf')
# params(count=0, eta=2e-06, noise=0.0, blur=0.5, number_of_neurons=20, sfname='sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 1 blur.asdf')
# params(count=0, eta=2e-06, noise=0.0, blur=1.0, number_of_neurons=20, sfname='sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 2 blur.asdf')
# params(count=0, eta=2e-06, noise=0.0, blur=1.5, number_of_neurons=20, sfname='sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 3 blur.asdf')
# params(count=0, eta=2e-06, noise=0.0, blur=2.0, number_of_neurons=20, sfname='sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 4 blur.asdf')
# params(count=0, eta=2e-06, noise=0.0, blur=2.5, number_of_neurons=20, sfname='sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 5 blur.asdf')
# params(count=0, eta=2e-06, noise=0.0, blur=3.0, number_of_neurons=20, sfname='sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 6 blur.asdf')
# params(count=0, eta=2e-06, noise=0.0, blur=3.5, number_of_neurons=20, sfname='sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 7 blur.asdf')
# params(count=0, eta=2e-06, noise=0.0, blur=4.0, number_of_neurons=20, sfname='sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 8 blur.asdf')
# params(count=0, eta=2e-06, noise=0.0, blur=4.5, number_of_neurons=20, sfname='sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 9 blur.asdf')
# 33
# 48 m, 48.75 s

# %%
do_params=make_do_params(all_params)
len(do_params)
# Out:
# 0

# %%
# %%time
run_one_left_blur(all_params[0],overwrite=True)
# Out:
# Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[.] Sequence Time Elapsed...5 m, 27.06 s
# CPU times: user 5min 26s, sys: 3.22 s, total: 5min 29s
# Wall time: 5min 30s
# 'sims/2022-11-03/deficit 20 neurons logdog 0 eta 0 noise 0 blur.asdf'

# %%
pool = Pool(processes=number_of_processes)
result = pool.map_async(run_one_left_blur, all_params)
print(result.get())
# Out:
# Using cache_images/cache_images_e45f122bfc50eb8c847eebf654d4e2f9.asdf from cache.Using cache_images/cache_images_62e306c692d6b83e3b77b80bc22e9a33.asdf from cache.Using cache_images/cache_images_fce2787b6851c4558bd86ff83040a315.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.Using cache_images/cache_images_3bf7e64753429eee85b2eabac938c9a5.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[[[[.] Sequence Time Elapsed...5 m, 38.74 s
# .] Sequence Time Elapsed...5 m, 38.94 s
# .] Sequence Time Elapsed...5 m, 39.51 s
# .] Sequence Time Elapsed...5 m, 40.26 s
# Using cache_images/cache_images_00d1d4d8408339943ebc3a91251e400e.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[Using cache_images/cache_images_76c3e4d6004f91ed664358fecb48a9a2.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[Using cache_images/cache_images_869749ae962a182d4c7f82825b597047.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[Using cache_images/cache_images_5e84bd5ab6331ff82a20b41ba99177f4.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[.] Sequence Time Elapsed...5 m, 40.54 s
# .] Sequence Time Elapsed...5 m, 41.11 s
# .] Sequence Time Elapsed...5 m, 40.01 s
# .] Sequence Time Elapsed...5 m, 41.41 s
# Using cache_images/cache_images_aa9417b46a2c6247c2a1ca74d50b1d36.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[Using cache_images/cache_images_3512c1afd204c730e5790e39db68766c.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[Using cache_images/cache_images_e9ec367b9bed67f47691bc1e5c542b78.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[Using cache_images/cache_images_3c6b4641e3b2fc312281b1f761760090.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[.] Sequence Time Elapsed...5 m, 46.00 s
# .] Sequence Time Elapsed...5 m, 45.45 s
# .] Sequence Time Elapsed...5 m, 47.73 s
# .] Sequence Time Elapsed...5 m, 48.49 s
# Using cache_images/cache_images_5f11b6fbb17d90ce76318f5ce873d817.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[Using cache_images/cache_images_b67dd0fc89592b3744d301386069d226.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[.] Sequence Time Elapsed...6 m, 14.68 s
# .] Sequence Time Elapsed...6 m, 13.74 s
# Using cache_images/cache_images_006b5329024d5a6b92e071d3966cc65d.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[.] Sequence Time Elapsed...5 m, 47.94 s
# Using cache_images/cache_images_cafbf71ebd457bf75b7a2d280a152172.asdf from cache.Using cache_images/cache_images_26c21bb98ee35e2306d1fd04c30276c2.asdf from cache.[.] Sequence Time Elapsed...5 m, 46.35 s
# ['sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 0 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 1 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 2 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 3 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 4 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 5 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 6 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 7 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 8 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 9 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 10 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 11 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 12 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 13 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 14 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 15 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 16 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 17 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 18 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 19 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 20 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 21 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 22 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 23 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 24 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 25 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 26 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 27 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 28 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 29 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 30 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 31 blur.asdf', 'sims/2022-11-03b/deficit 20 neurons logdog 0 eta 0 noise 32 blur.asdf']

# %%
# %%time
RR={}
count=0
for params in all_params:
    RR[params.sfname]=Results(params.sfname)
# Out:
# CPU times: user 31.2 s, sys: 3.1 s, total: 34.3 s
# Wall time: 34.6 s

# %%
s=Storage()
count=0
for blur_count,blur in enumerate(blur_mat):
    params=all_params[count]
    count+=1
    R=RR[params.sfname]
    blur=params.blur
    μ1,μ2=R.μσ[0][0]
    σ1,σ2=R.μσ[1][0]

    s+=blur,μ1,μ2,σ1,σ2

blur,μ1,μ2,σ1,σ2=s.arrays()
figure()
errorbar(blur,μ1,yerr=2*σ1,marker='o',elinewidth=1,label='Deprived',color=cm.Oranges(0.7))
errorbar(blur,μ2,yerr=2*σ2,marker='s',elinewidth=1,label='Fellow',color=cm.Blues(0.7))
xlabel('Blur Size [pixels]')
ylabel('Maximum Response')
legend()
title('Blur after difference-of-Gaussians')
# Out:
# Text(0.5, 1.0, 'Blur after difference-of-Gaussians')
