# %%
# %matplotlib inline
from pylab import *
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
from treatment_sims_2023_06_02 import *
# Out:
# Splikes version  0.1.2
# Plasticnet version  0.1.9
# macOS-10.16-x86_64-i386-64bit

# %%
base='sims/2023-06-26'
deficit_base='sims/2023-06-02'
if not os.path.exists(base):
    print(f"mkdir {base}")
    os.mkdir(base)
# Out:
# mkdir sims/2023-06-26

# %% [markdown]
# ## Just do the patch for twice as long
#
# this is to answer the question:  why not reverse amblyopia in the case of patch treatment?

# %%
rf_size=19
eta=1e-6
number_of_neurons=25
number_of_processes=4
mu_c_mat=[0,7.5,0,7.5]
sigma_c_mat=[0,2,2,0]
blur=4
noise_mat=linspace(0,1,21)
noise_mat
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])

# %%
from collections import namedtuple
params = namedtuple('params', ['count', 'eta','noise','blur','number_of_neurons','sfname','mu_c','sigma_c'])
all_params=[]
count=0
eta_count=0
noise_count=0


for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    for noise_count,closed_eye_noise in enumerate(noise_mat):
        all_params.append(params(count=count,
                     eta=eta,
                     noise=closed_eye_noise,
                         blur=blur,
                     number_of_neurons=number_of_neurons,
         sfname=f'{base}/patch {number_of_neurons} neurons {mu_c} mu_c {sigma_c} sigma_c {blur} blur {closed_eye_noise:.1f} noise.asdf',
                    mu_c=mu_c,sigma_c=sigma_c))

        count+=1

for a in all_params[:5]:
    print(a)
print("[....]")
for a in all_params[-5:]:
    print(a)


for a in all_params[:5]:
    print(a)
print("[....]")
for a in all_params[-5:]:
    print(a)
# Out:
# params(count=0, eta=1e-06, noise=0.0, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.0 noise.asdf', mu_c=0, sigma_c=0)
# params(count=1, eta=1e-06, noise=0.05, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.1 noise.asdf', mu_c=0, sigma_c=0)
# params(count=2, eta=1e-06, noise=0.1, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.1 noise.asdf', mu_c=0, sigma_c=0)
# params(count=3, eta=1e-06, noise=0.15000000000000002, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.2 noise.asdf', mu_c=0, sigma_c=0)
# params(count=4, eta=1e-06, noise=0.2, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.2 noise.asdf', mu_c=0, sigma_c=0)
# [....]
# params(count=79, eta=1e-06, noise=0.8, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.8 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=80, eta=1e-06, noise=0.8500000000000001, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.9 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=81, eta=1e-06, noise=0.9, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.9 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=82, eta=1e-06, noise=0.9500000000000001, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 1.0 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=83, eta=1e-06, noise=1.0, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 1.0 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=0, eta=1e-06, noise=0.0, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.0 noise.asdf', mu_c=0, sigma_c=0)
# params(count=1, eta=1e-06, noise=0.05, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.1 noise.asdf', mu_c=0, sigma_c=0)
# params(count=2, eta=1e-06, noise=0.1, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.1 noise.asdf', mu_c=0, sigma_c=0)
# params(count=3, eta=1e-06, noise=0.15000000000000002, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.2 noise.asdf', mu_c=0, sigma_c=0)
# params(count=4, eta=1e-06, noise=0.2, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.2 noise.asdf', mu_c=0, sigma_c=0)
# [....]
# params(count=79, eta=1e-06, noise=0.8, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.8 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=80, eta=1e-06, noise=0.8500000000000001, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.9 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=81, eta=1e-06, noise=0.9, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.9 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=82, eta=1e-06, noise=0.9500000000000001, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 1.0 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=83, eta=1e-06, noise=1.0, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 1.0 noise.asdf', mu_c=7.5, sigma_c=0)

# %%
blur
# Out:
# 4

# %% [markdown]
# ## Premake the image files

# %%
base_image_file='asdf/bbsk081604_all_scale2.asdf'
print("Base Image File:",base_image_file)

normal_image=pi5.filtered_images(
                                base_image_file,
                                {'type':'dog','sd1':1,'sd2':3},
                                {'type':'norm'},
                                )

Lfname=pi5.filtered_images(
                            base_image_file,
                            {'type':'blur','size':blur},
                            {'type':'dog','sd1':1,'sd2':3},
                            {'type':'norm'},
                            )
# Out:
# Base Image File: asdf/bbsk081604_all_scale2.asdf
# Using cache_images/cache_images_f6d484251bbeda8699ed0b15303a996c.asdf from cache.Using cache_images/cache_images_b0fdf9b6c831fb574442b0a3cfb98dd9.asdf from cache.

# %% [markdown]
# ## Functions for patch

# %%
def run_one_continuous_patch_jitter(params,
                                    overwrite=False,
                                 run=True):
    import plasticnet as pn
    count,eta,noise,blur,mu_c,sigma_c,number_of_neurons,sfname=(params.count,params.eta,params.noise,
                        params.blur,
                        params.mu_c,params.sigma_c,params.number_of_neurons,params.sfname)
    
    if not overwrite and os.path.exists(sfname):
        return sfname

    seq=pn.Sequence()
    deficit_base_sim=f'{deficit_base}/deficit {number_of_neurons} neurons {mu_c} mu_c {sigma_c} sigma_c {blur} blur.asdf'
    

    seq+=patch_treatment_jitter(patch_noise=noise,
               total_time=16*day,number_of_neurons=params.number_of_neurons,
            mu_c=mu_c,sigma_c=sigma_c,
               eta=eta,
               save_interval=20*minute)

    seq_load(seq,deficit_base_sim)    

    if run:
        seq.run(display_hash=False)
        pn.save(sfname,seq) 
    
    return sfname

# %%
func=run_one_continuous_patch_jitter

# %%
do_params=make_do_params(all_params)
len(do_params)
# Out:
# 84

# %%
# %%time
print(func.__name__)
func(all_params[0],overwrite=True)
# Out:
# run_one_continuous_patch_jitter
# [.] Sequence Time Elapsed...5 m, 19.93 s
# CPU times: user 14min 1s, sys: 5min 29s, total: 19min 30s
# Wall time: 5min 34s
# 'sims/2023-06-02/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.0 noise.asdf'

# %%
real_time=10*60+ 19

# %%
if len(do_params)>13:
    for a in do_params[:5]:
        print(a)
    print("[....]")
    for a in do_params[-5:]:
        print(a)
else:
    for a in do_params:
        print(a)
    

print(len(do_params))

print(time2str(real_time*len(do_params)/number_of_processes))
# Out:
# params(count=0, eta=1e-06, noise=0.0, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.0 noise.asdf', mu_c=0, sigma_c=0)
# params(count=1, eta=1e-06, noise=0.05, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.1 noise.asdf', mu_c=0, sigma_c=0)
# params(count=2, eta=1e-06, noise=0.1, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.1 noise.asdf', mu_c=0, sigma_c=0)
# params(count=3, eta=1e-06, noise=0.15000000000000002, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.2 noise.asdf', mu_c=0, sigma_c=0)
# params(count=4, eta=1e-06, noise=0.2, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.2 noise.asdf', mu_c=0, sigma_c=0)
# [....]
# params(count=79, eta=1e-06, noise=0.8, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.8 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=80, eta=1e-06, noise=0.8500000000000001, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.9 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=81, eta=1e-06, noise=0.9, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.9 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=82, eta=1e-06, noise=0.9500000000000001, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 1.0 noise.asdf', mu_c=7.5, sigma_c=0)
# params(count=83, eta=1e-06, noise=1.0, blur=4, number_of_neurons=25, sfname='sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 1.0 noise.asdf', mu_c=7.5, sigma_c=0)
# 84
# 3 h, 36 m, 39.00 s

# %%
if do_params:
    pool = Pool(processes=number_of_processes)
    async_results = [pool.apply_async(func, args=(p,),kwds={'overwrite':False,'run':True}) 
                             for p in do_params]
    results =[_.get() for _ in async_results]
    
results
# Out:
# [[[[.] Sequence Time Elapsed...12 m, 45.77 s
# .] Sequence Time Elapsed...12 m, 47.67 s
# .] Sequence Time Elapsed...12 m, 47.96 s
# .] Sequence Time Elapsed...12 m, 48.11 s
# [[[[.] Sequence Time Elapsed...12 m, 11.38 s
# .] Sequence Time Elapsed...12 m, 9.71 s
# .] Sequence Time Elapsed...12 m, 11.08 s
# .] Sequence Time Elapsed...12 m, 12.04 s
# [[[[.] Sequence Time Elapsed...12 m, 32.97 s
# .] Sequence Time Elapsed...12 m, 35.52 s
# .] Sequence Time Elapsed...12 m, 33.65 s
# .] Sequence Time Elapsed...12 m, 34.97 s
# [[[[.] Sequence Time Elapsed...12 m, 24.09 s
# .] Sequence Time Elapsed...12 m, 27.69 s
# .] Sequence Time Elapsed...12 m, 26.15 s
# .] Sequence Time Elapsed...12 m, 26.09 s
# [[[[.] Sequence Time Elapsed...12 m, 18.35 s
# .] Sequence Time Elapsed...12 m, 18.40 s
# .] Sequence Time Elapsed...12 m, 19.09 s
# .] Sequence Time Elapsed...12 m, 18.07 s
# [[[[.] Sequence Time Elapsed...12 m, 45.50 s
# .] Sequence Time Elapsed...12 m, 46.54 s
# .] Sequence Time Elapsed...12 m, 46.74 s
# .] Sequence Time Elapsed...12 m, 47.05 s
# [[[[.] Sequence Time Elapsed...12 m, 55.87 s
# .] Sequence Time Elapsed...12 m, 55.00 s
# .] Sequence Time Elapsed...12 m, 55.57 s
# .] Sequence Time Elapsed...12 m, 52.74 s
# [[[[.] Sequence Time Elapsed...12 m, 45.37 s
# .] Sequence Time Elapsed...12 m, 45.10 s
# .] Sequence Time Elapsed...12 m, 46.13 s
# .] Sequence Time Elapsed...12 m, 44.75 s
# [[[[.] Sequence Time Elapsed...12 m, 44.59 s
# .] Sequence Time Elapsed...12 m, 44.59 s
# .] Sequence Time Elapsed...12 m, 44.74 s
# .] Sequence Time Elapsed...12 m, 43.86 s
# [[[[.] Sequence Time Elapsed...12 m, 59.37 s
# .] Sequence Time Elapsed...12 m, 59.19 s
# .] Sequence Time Elapsed...13 m, 0.53 s
# .] Sequence Time Elapsed...12 m, 59.83 s
# [[[[.] Sequence Time Elapsed...12 m, 38.87 s
# .] Sequence Time Elapsed...12 m, 41.50 s
# .] Sequence Time Elapsed...12 m, 39.19 s
# .] Sequence Time Elapsed...12 m, 40.70 s
# [[[[.] Sequence Time Elapsed...12 m, 49.28 s
# .] Sequence Time Elapsed...12 m, 50.31 s
# .] Sequence Time Elapsed...12 m, 49.72 s
# .] Sequence Time Elapsed...12 m, 47.17 s
# [[[[.] Sequence Time Elapsed...12 m, 39.85 s
# .] Sequence Time Elapsed...12 m, 39.61 s
# .] Sequence Time Elapsed...12 m, 38.43 s
# .] Sequence Time Elapsed...12 m, 39.86 s
# [[[[.] Sequence Time Elapsed...12 m, 40.36 s
# .] Sequence Time Elapsed...12 m, 40.02 s
# .] Sequence Time Elapsed...12 m, 38.56 s
# .] Sequence Time Elapsed...12 m, 35.98 s
# [[[[.] Sequence Time Elapsed...12 m, 37.35 s
# .] Sequence Time Elapsed...12 m, 37.49 s
# .] Sequence Time Elapsed...12 m, 36.40 s
# .] Sequence Time Elapsed...12 m, 36.82 s
# [[[[.] Sequence Time Elapsed...12 m, 19.81 s
# .] Sequence Time Elapsed...12 m, 17.37 s
# .] Sequence Time Elapsed...12 m, 16.54 s
# .] Sequence Time Elapsed...12 m, 14.04 s
# [[[[.] Sequence Time Elapsed...12 m, 2.20 s
# .] Sequence Time Elapsed...12 m, 1.48 s
# .] Sequence Time Elapsed...11 m, 58.69 s
# .] Sequence Time Elapsed...11 m, 59.81 s
# [[[[.] Sequence Time Elapsed...12 m, 54.42 s
# .] Sequence Time Elapsed...12 m, 56.03 s
# [.] Sequence Time Elapsed...12 m, 56.09 s
# .] Sequence Time Elapsed...12 m, 56.60 s
# [[[.] Sequence Time Elapsed...12 m, 54.28 s
# [.] Sequence Time Elapsed...12 m, 56.23 s
# .] Sequence Time Elapsed...12 m, 53.25 s
# .] Sequence Time Elapsed...12 m, 54.55 s
# [[[.] Sequence Time Elapsed...12 m, 48.82 s
# [.] Sequence Time Elapsed...12 m, 48.78 s
# .] Sequence Time Elapsed...12 m, 47.99 s
# .] Sequence Time Elapsed...12 m, 48.49 s
# [[[.] Sequence Time Elapsed...12 m, 55.11 s
# .] Sequence Time Elapsed...12 m, 53.00 s
# .] Sequence Time Elapsed...12 m, 52.39 s
# .] Sequence Time Elapsed...12 m, 52.35 s
# ['sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.0 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.1 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.1 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.3 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.4 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.4 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.5 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.5 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.6 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.6 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.7 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.7 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.8 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.8 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.9 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 0.9 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 1.0 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 0 sigma_c 4 blur 1.0 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.0 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.1 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.1 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.3 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.4 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.4 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.5 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.5 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.6 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.6 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.7 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.7 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.8 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.8 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.9 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 0.9 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 1.0 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 2 sigma_c 4 blur 1.0 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.0 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.1 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.1 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.3 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.4 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.4 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.5 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.5 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.6 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.6 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.7 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.7 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.8 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.8 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.9 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 0.9 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 1.0 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 0 mu_c 2 sigma_c 4 blur 1.0 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.0 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.1 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.1 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.2 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.3 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.4 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.4 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.5 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.5 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.6 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.6 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.7 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.7 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.8 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.8 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.9 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.9 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 1.0 noise.asdf',
#  'sims/2023-06-26/patch 25 neurons 7.5 mu_c 0 sigma_c 4 blur 1.0 noise.asdf']

# %% [markdown]
# ## View the sims

# %%
sfname=all_params[0].sfname
R=Results(sfname)

# %%
t,y,θ,W=R[-1]
vmin=W.min()
vmax=W.max()

w_im=R.weight_image(W)
count=1
for n in range(4):
    for c in range(2):
        subplot(4,2,count)
        pcolormesh(w_im[n,c,...],cmap=py.cm.gray,
                        vmin=vmin,vmax=vmax)
        ax2=gca()
        ax2.set_aspect('equal')
        ax2.set_xticklabels([])
        ax2.set_yticklabels([])
        ax2.xaxis.set_ticks_position('none') 
        ax2.yaxis.set_ticks_position('none') 
        
        count+=1
# Out:
# /Users/bblais/tmp/ipykernel_11329/1582112873.py:10: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   pcolormesh(w_im[n,c,...],cmap=py.cm.gray,

# %%
RR={}
count=0
for params in tqdm(all_params):
    RR[params.sfname]=Results(params.sfname)
# Out:
#   0%|          | 0/84 [00:00<?, ?it/s]

# %% [markdown]
# ![image.png](attachment:aebd2839-95ec-49e3-9ab4-d83fb6e2d3f9.png)

# %%
count=0
for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    s=Storage()
    for noise_count,noise in enumerate(noise_mat):
        open_eye_noise=noise
        params=all_params[count]
        count+=1
        R=RR[params.sfname]
        noise=params.noise
        μ1,μ2=R.μσ[0][0]
        σ1,σ2=R.μσ[1][0]

        s+=noise,μ1,μ2,σ1,σ2


    noise,μ1,μ2,σ1,σ2=s.arrays()

    figure()
    errorbar(noise,μ1,yerr=2*σ1,marker='o',elinewidth=1,label='Amblyopic')
    errorbar(noise,μ2,yerr=2*σ2,marker='s',elinewidth=1,label='Fellow')
    xlabel('Noise')
    ylabel('Maximum Response')
    title(f'μc={mu_c} σc={sigma_c} blur={blur}')
    legend()

# %%
v=np.flip(linspace(0.3,1,4))

count=0
idx=0
for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    s=Storage()
    for noise_count,noise in enumerate(noise_mat):
        open_eye_noise=noise
        params=all_params[count]
        count+=1
        R=RR[params.sfname]
        noise=params.noise
        μ1,μ2=R.μσ[0][0]
        σ1,σ2=R.μσ[1][0]

        s+=noise,μ1,μ2,σ1,σ2


    noise,μ1,μ2,σ1,σ2=s.arrays()

    if idx==2:
        errorbar(noise,μ1,yerr=2*σ1,marker='o',elinewidth=1,label=f'Amblyopic',color=cm.Blues(v[idx]))
        errorbar(noise,μ2,yerr=2*σ2,marker='s',elinewidth=1,label=f'Fellow',color=cm.Oranges(v[idx]))
    else:
        errorbar(noise,μ1,yerr=2*σ1,marker='o',elinewidth=1,label='_',color=cm.Blues(v[idx]))
        errorbar(noise,μ2,yerr=2*σ2,marker='s',elinewidth=1,label='_',color=cm.Oranges(v[idx]))
        
        
    dy=.5
    text(-.05,μ1[:1]+dy,f'μ={mu_c} σ={sigma_c}',va='center',ha='right',size=8,color=cm.Blues(v[0]))         
    text(-.05,μ2[:1]-dy,f'μ={mu_c} σ={sigma_c}',va='center',ha='right',size=8,color=cm.Oranges(v[0]))
    
    idx+=1        
    
xlabel('Closed-eye Noise')
ylabel('Maximum Response')
legend()    
# gca().set_xticks(range(0,13,2))
xlim([-.2,1.105])
# Out:
# (-0.2, 1.105)

# %%
v=np.flip(linspace(0.3,1,4))

count=0
idx=0
for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    s=Storage()
    for noise_count,noise in enumerate(noise_mat):
        open_eye_noise=noise
        params=all_params[count]
        count+=1
        R=RR[params.sfname]
        noise=params.noise
        μ,σ=μσ(R.ODI[-1])
        
        s+=noise,μ,σ


    noise,μ,σ=s.arrays()

    errorbar(noise,μ,yerr=2*σ,marker='o',elinewidth=1,label=f'μ={mu_c} σ={sigma_c}',color=cm.viridis(1-v[idx]))
    
    idx+=1
    
xlabel('Closed-eye Noise')
ylabel(r'$\longleftarrow$ Weak Eye              Strong Eye $\longrightarrow$'+"\nODI")

legend()  
ylim([-1,1])
xl=xlim()
plot(xl,[0,0],'k-',lw=2)

# gca().set_xticks(range(0,13,2))

# %%
v=np.flip(linspace(0.3,1,4))

count=0
idx=0
for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    s=Storage()
    for noise_count,noise in enumerate(noise_mat):
        open_eye_noise=noise
        params=all_params[count]
        count+=1
        R=RR[params.sfname]
        noise=params.noise
        t=R.t/day
        recovery_rate_μ,recovery_rate_σ=μσ((R.ODI[-1,:]-R.ODI[0,:])/(t[-1]-t[0]))  
    
        s+=noise,recovery_rate_μ,recovery_rate_σ


    noise,μ,σ=s.arrays()

    errorbar(noise,-μ,yerr=2*σ,marker='o',elinewidth=1,label=f'μ={mu_c} σ={sigma_c}',color=cm.viridis(1-v[idx]))
    
    idx+=1
    
xlabel('Closed-eye Noise')
ylabel(r'$\longleftarrow$ Slower recovery     Faster Recovery $\longrightarrow$'+"\n[ODI shift/time]")


legend()

# %%
figure(figsize=(25,16))
subplot(2,2,1)

v=np.flip(linspace(0.3,1,4))

count=0
idx=0
for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    s=Storage()
    for noise_count,noise in enumerate(noise_mat):
        open_eye_noise=noise
        params=all_params[count]
        count+=1
        R=RR[params.sfname]
        noise=params.noise
        μ1,μ2=R.μσ[0][0]
        σ1,σ2=R.μσ[1][0]

        s+=noise,μ1,μ2,σ1,σ2


    noise,μ1,μ2,σ1,σ2=s.arrays()

    if idx==2:
        errorbar(noise,μ1,yerr=2*σ1,marker='o',elinewidth=1,label=f'Amblyopic',color=cm.Blues(v[idx]))
        errorbar(noise,μ2,yerr=2*σ2,marker='s',elinewidth=1,label=f'Fellow',color=cm.Oranges(v[idx]))
    else:
        errorbar(noise,μ1,yerr=2*σ1,marker='o',elinewidth=1,label='_',color=cm.Blues(v[idx]))
        errorbar(noise,μ2,yerr=2*σ2,marker='s',elinewidth=1,label='_',color=cm.Oranges(v[idx]))
        
        
    dy=.5
    text(-.05,μ1[:1]+dy,f'μ={mu_c} σ={sigma_c}',va='center',ha='right',size=8,color=cm.Blues(v[0]))         
    text(-.05,μ2[:1]-dy,f'μ={mu_c} σ={sigma_c}',va='center',ha='right',size=8,color=cm.Oranges(v[0]))
    
    idx+=1        
    
xlabel('Closed-eye Noise')
ylabel('Maximum Response')
legend()    
# gca().set_xticks(range(0,13,2))
xlim([-.2,1.105])

subplot(2,2,2)
v=np.flip(linspace(0.3,1,4))

count=0
idx=0
for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    s=Storage()
    for noise_count,noise in enumerate(noise_mat):
        open_eye_noise=noise
        params=all_params[count]
        count+=1
        R=RR[params.sfname]
        noise=params.noise
        μ,σ=μσ(R.ODI[-1])
        
        s+=noise,μ,σ


    noise,μ,σ=s.arrays()

    errorbar(noise,μ,yerr=2*σ,marker='o',elinewidth=1,label=f'μ={mu_c} σ={sigma_c}',color=cm.viridis(1-v[idx]))
    
    idx+=1
    
xlabel('Closed-eye Noise')
ylabel(r'$\longleftarrow$ Amblyopic Eye              Fellow Eye $\longrightarrow$'+"\nODI")

legend()  
ylim([-1,1])
xl=xlim()
plot(xl,[0,0],'k-',lw=2)

# gca().set_xticks(range(0,13,2))


ax=subplot(2,2,3)
pos=ax.get_position().bounds
ax.set_position([pos[0]+.2,pos[1],pos[2],pos[3]])

v=np.flip(linspace(0.3,1,4))

count=0
idx=0
for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    s=Storage()
    for noise_count,noise in enumerate(noise_mat):
        open_eye_noise=noise
        params=all_params[count]
        count+=1
        R=RR[params.sfname]
        noise=params.noise
        t=R.t/day
        recovery_rate_μ,recovery_rate_σ=μσ((R.ODI[-1,:]-R.ODI[0,:])/(t[-1]-t[0]))  
    
        s+=noise,recovery_rate_μ,recovery_rate_σ


    noise,μ,σ=s.arrays()

    errorbar(noise,-μ,yerr=2*σ,marker='o',elinewidth=1,label=f'μ={mu_c} σ={sigma_c}',color=cm.viridis(1-v[idx]))
    
    idx+=1
    
xlabel('Closed-eye Noise')
ylabel(r'$\longleftarrow$ Slower recovery     Faster Recovery $\longrightarrow$'+"\n[ODI shift/time]")


legend()  
    
    
    
plt.text(.1, 0.9, "A", transform=plt.gcf().transFigure,
    fontsize=26, fontweight='bold', va='top')

plt.text(.5, 0.9, "B", transform=plt.gcf().transFigure,
    fontsize=26, fontweight='bold', va='top')


plt.text(.23, 0.46, "C", transform=plt.gcf().transFigure,
    fontsize=26, fontweight='bold', va='top')

savefig('fig-patch-response-ODI-blur-long.png')
# Out:
# Manuscript/resources/fig-patch-response-ODI-blur-long.png
# Manuscript/resources/fig-patch-response-ODI-blur-long.svg
