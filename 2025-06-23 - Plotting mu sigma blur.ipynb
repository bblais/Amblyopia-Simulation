# %%
from pylab import *

# %%
from deficit_defs_2025_02_25 import *
# Out:
# Splikes version  0.1.5
# Plasticnet version  0.1.14
# macOS-15.5-arm64-arm-64bit
# Base Image File: asdf/bbsk081604_all_scale2.asdf

# %%
base_sim_dir=f"sims-2025-06-04 mu_c sigma_c blur"
if not os.path.exists(base_sim_dir):
    print("new")
    os.mkdir(base_sim_dir)
print(base_sim_dir)
# Out:
# sims-2025-06-04 mu_c sigma_c blur

# %%
loadvars(f'{base_sim_dir}/deficit_results.asdf')
# Out:
# Found ['subResults', 'mu_c_mat', 'blur_mat']

# %%
len(subResults)
# Out:
# 221

# %%
fnames=list(subResults.keys())

# %%
R=Struct(subResults[fnames[0]])

# %%
R.y.shape
# Out:
# (385, 20, 2)

# %%
μσ(R.y[-1,:,:],axis=0)
# Out:
# (array([28.24195574, 27.89004194]), array([1.70613989, 1.83719781]))

# %%
(μ1,μ2),(σ1,σ2)=μσ(R.y[-1,:,:],axis=0)

# %%
(μ1,μ2),(σ1,σ2)
# Out:
# ((28.241955736725686, 27.890041937149373),
#  (1.7061398912984949, 1.8371978129139845))

# %%
count=0
for blur_count,blur in enumerate(blur_mat):
    for mu_count,mu_c in tqdm(enumerate(mu_c_mat)):
        R=Struct(subResults[fnames[count]])
        params=Struct(R.params)
        sigma_c=params.sigma_c
        print(fnames[count])
        print("\tBlur",blur,params.blur[0])
        print("\tmu_c",mu_c,params.mu_c)
        print("\tsigma_c",sigma_c)
        count+=1

        if count>10:
            break
# Out:
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 0.0 sigma_c 2.0.asdf
# 	Blur 0.0 0.0
# 	mu_c 0.0 0.0
# 	sigma_c 2.0
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 10.0 sigma_c 2.0.asdf
# 	Blur 0.0 0.0
# 	mu_c 2.5 10.0
# 	sigma_c 2.0
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 12.5 sigma_c 2.0.asdf
# 	Blur 0.0 0.0
# 	mu_c 5.0 12.5
# 	sigma_c 2.0
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 15.0 sigma_c 2.0.asdf
# 	Blur 0.0 0.0
# 	mu_c 7.5 15.0
# 	sigma_c 2.0
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 17.5 sigma_c 2.0.asdf
# 	Blur 0.0 0.0
# 	mu_c 10.0 17.5
# 	sigma_c 2.0
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 2.5 sigma_c 2.0.asdf
# 	Blur 0.0 0.0
# 	mu_c 12.5 2.5
# 	sigma_c 2.0
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 20.0 sigma_c 2.0.asdf
# 	Blur 0.0 0.0
# 	mu_c 15.0 20.0
# 	sigma_c 2.0
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 22.5 sigma_c 2.0.asdf
# 	Blur 0.0 0.0
# 	mu_c 17.5 22.5
# 	sigma_c 2.0
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 25.0 sigma_c 2.0.asdf
# 	Blur 0.0 0.0
# 	mu_c 20.0 25.0
# 	sigma_c 2.0
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 27.5 sigma_c 2.0.asdf
# 	Blur 0.0 0.0
# 	mu_c 22.5 27.5
# 	sigma_c 2.0
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 30.0 sigma_c 2.0.asdf
# 	Blur 0.0 0.0
# 	mu_c 25.0 30.0
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 5.0 sigma_c 2.0.asdf
# 	Blur 0.5 0.0
# 	mu_c 0.0 5.0
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.0 mu_c 7.5 sigma_c 2.0.asdf
# 	Blur 1.0 0.0
# 	mu_c 0.0 7.5
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 0.0 sigma_c 2.0.asdf
# 	Blur 1.5 0.5
# 	mu_c 0.0 0.0
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 10.0 sigma_c 2.0.asdf
# 	Blur 2.0 0.5
# 	mu_c 0.0 10.0
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 12.5 sigma_c 2.0.asdf
# 	Blur 2.5 0.5
# 	mu_c 0.0 12.5
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 15.0 sigma_c 2.0.asdf
# 	Blur 3.0 0.5
# 	mu_c 0.0 15.0
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 17.5 sigma_c 2.0.asdf
# 	Blur 3.5 0.5
# 	mu_c 0.0 17.5
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 2.5 sigma_c 2.0.asdf
# 	Blur 4.0 0.5
# 	mu_c 0.0 2.5
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 20.0 sigma_c 2.0.asdf
# 	Blur 4.5 0.5
# 	mu_c 0.0 20.0
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 22.5 sigma_c 2.0.asdf
# 	Blur 5.0 0.5
# 	mu_c 0.0 22.5
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 25.0 sigma_c 2.0.asdf
# 	Blur 5.5 0.5
# 	mu_c 0.0 25.0
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 27.5 sigma_c 2.0.asdf
# 	Blur 6.0 0.5
# 	mu_c 0.0 27.5
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 30.0 sigma_c 2.0.asdf
# 	Blur 6.5 0.5
# 	mu_c 0.0 30.0
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 5.0 sigma_c 2.0.asdf
# 	Blur 7.0 0.5
# 	mu_c 0.0 5.0
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 0.5 mu_c 7.5 sigma_c 2.0.asdf
# 	Blur 7.5 0.5
# 	mu_c 0.0 7.5
# 	sigma_c 2.0
# 0it [00:00, ?it/s]
# sims-2025-06-04 mu_c sigma_c blur/deficit 20 neurons noise 0.1 blur 1.0 mu_c 0.0 sigma_c 2.0.asdf
# 	Blur 8.0 1.0
# 	mu_c 0.0 0.0
# 	sigma_c 2.0

# %%
count=0
sigma_c=2.0
number_of_neurons=20
open_eye_noise=0.1

for mu_count,mu_c in tqdm(enumerate(mu_c_mat)):
    s=Storage()
    for blur_count,blur in enumerate(blur_mat):
        sfname=f'{base_sim_dir}/deficit {number_of_neurons} neurons noise {open_eye_noise:.1f} blur {blur:.1f} mu_c {mu_c:.1f} sigma_c {sigma_c:.1f}.asdf'
        R=Struct(subResults[sfname])
        params=Struct(R.params)
        blur=params.blur[0]
        sigma_c=params.sigma_c
        (μ1,μ2),(σ1,σ2)=μσ(R.y[-1,:,:],axis=0)

        s+=blur,μ1,μ2,σ1,σ2
        count+=1
    
    
    blur,μ1,μ2,σ1,σ2=s.arrays()
    
    figure()
    errorbar(blur,μ1,yerr=2*σ1,marker='o',elinewidth=1,label='Deprived')
    errorbar(blur,μ2,yerr=2*σ2,marker='s',elinewidth=1,label='Normal')
    xlabel('Blur Size [pixels]')
    ylabel('Maximum Response')
    title(f'μ_c={mu_c},σ_c={sigma_c}')
    legend()
# Out:
# 0it [00:00, ?it/s]

# %%
count=0
v=np.flip(linspace(0.3,1,len(mu_c_mat)))

for mu_count,mu_c in enumerate(mu_c_mat):
    s=Storage()
    for blur_count,blur in enumerate(blur_mat):
        if blur==0.5:
            continue
        
        sfname=f'{base_sim_dir}/deficit {number_of_neurons} neurons noise {open_eye_noise:.1f} blur {blur:.1f} mu_c {mu_c:.1f} sigma_c {sigma_c:.1f}.asdf'
        R=Struct(subResults[sfname])
        μ,σ=μσ(R.ODI[-1])

        s+=blur,μ,σ
        count+=1
    
    
    blur,μ,σ=s.arrays()
    errorbar(blur,μ,yerr=2*σ,marker='o',elinewidth=1,color=cm.Oranges(v[mu_count]))    
    xlabel('Blur Size [pixels]')
    ylabel(r'$\longleftarrow$ Weak Eye              Strong Eye $\longrightarrow$'+"\nODI")
    ylim([-1,1])

divider = make_axes_locatable(plt.gca())
ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
ax_cb2.grid(False)
cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=Oranges2,norm=mpl.colors.Normalize(vmin=mu_c_mat[0], vmax=mu_c_mat[-1]),orientation='vertical')
ax_cb2.grid(True)
plt.gcf().add_axes(ax_cb2)
title(r'$\mu_c$')
# Out:
# Text(0.5, 1.0, '$\\mu_c$')
