# %%
base_image_file='asdf/bbsk081604_all_scale2.asdf'

# %%
# %matplotlib inline
from pylab import *

# %%
import process_images_hdf5 as pi5

# %%
# imfname=pi5.filtered_images(base_image_file,
#                                         {'type':'mask',
#                                          'name':'', 
#                                         'seed':101,'apply_to_average':True},
#                                         {'type':'norm'},
#                                         {'type':'dog','sd1':1,'sd2':3},
# )

# %%
mask_name='F'
f=10
f'bblais-masks-20240511/2024-05-11-*-{mask_name}-fsig{int(f)}.png'
# Out:
# 'bblais-masks-20240511/2024-05-11-*-F-fsig10.png'

# %%
from glob import glob

# %%
glob('bblais-masks-20240511/2024-05-11-*-F-fsig10.png')
# Out:
# ['bblais-masks-20240511/2024-05-11-C-F-fsig10.png',
#  'bblais-masks-20240511/2024-05-11-D-F-fsig10.png',
#  'bblais-masks-20240511/2024-05-11-E-F-fsig10.png',
#  'bblais-masks-20240511/2024-05-11-B-F-fsig10.png',
#  'bblais-masks-20240511/2024-05-11-A-F-fsig10.png']

# %%
import os
if os.path.exists('cache_images/cache_images_79ae0d4f704f32edda0f9299d1f2d599.asdf'):
    print("Deleting cache file")
    os.remove('cache_images/cache_images_79ae0d4f704f32edda0f9299d1f2d599.asdf')


if os.path.exists('cache_images/cache_images_ffae122e3abc8831bd00f07945aabfd5.asdf'):
    print("Deleting cache file")
    os.remove('cache_images/cache_images_ffae122e3abc8831bd00f07945aabfd5.asdf')

# %%
full_Fmask_name=f'bblais-masks-20240511/2024-05-11-E-F-fsig{int(f)}.png'
full_Amask_name=f'bblais-masks-20240511/2024-05-11-E-A-fsig{int(f)}.png'

# %%
imfname=pi5.filtered_images(base_image_file,
                                        {'type':'mask',
                                         'name':full_Fmask_name, 
                                        'seed':101,'apply_to_average':True},
                                        {'type':'norm'},
                                        verbose=False,
                                         )

# %%
im=imread(full_Fmask_name)
imshow(im)

# %%
image_data=pi5.asdf_load_images(imfname)
im1=image_data['im'][5]*image_data['im_scale_shift'][0]+image_data['im_scale_shift'][1]
imshow(im1,cmap=cm.gray)
axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
mask_name='A'
imfname=pi5.filtered_images(base_image_file,
                                        {'type':'mask',
                                         'name':full_Amask_name, 
                                        'seed':101,'apply_to_average':True},
                                        {'type':'norm'},
                                        verbose=False,
                                         )
# Out:
# Mask bblais-masks-20240511/2024-05-11-E-A-fsig10.png (applied to average)
#  [#############################100% (ETA: 0.0 s)#############################]

# %%
image_data=pi5.asdf_load_images(imfname)
im1=image_data['im'][5]*image_data['im_scale_shift'][0]+image_data['im_scale_shift'][1]
imshow(im1,cmap=cm.gray)
axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
mask_name='F'
imfname=pi5.filtered_images(base_image_file,
                                        {'type':'mask',
                                         'name':full_Fmask_name, 
                                        'seed':101,'apply_to_average':True},
                                        {'type':'norm'},
                                        {'type':'dog','sd1':1,'sd2':3},   
                                        verbose=True,
                                         )
image_data=pi5.asdf_load_images(imfname)
im1=image_data['im'][5]*image_data['im_scale_shift'][0]+image_data['im_scale_shift'][1]
figure()
imshow(im1,cmap=cm.gray)
axis('off')

mask_name='A'
imfname=pi5.filtered_images(base_image_file,
                                        {'type':'mask',
                                         'name':full_Amask_name, 
                                        'seed':101,'apply_to_average':True},
                                        {'type':'norm'},
                                        {'type':'dog','sd1':1,'sd2':3},   
                                        verbose=True,
                                         )
image_data=pi5.asdf_load_images(imfname)
im1=image_data['im'][5]*image_data['im_scale_shift'][0]+image_data['im_scale_shift'][1]
figure()
imshow(im1,cmap=cm.gray)
axis('off')
# Out:
# Actual masks:  b,b,l,a,i,s,-,m,a,s,k,s,-,2,0,2,4,0,5,1,1,/,2,0,2,4,-,0,5,-,1,1,-,E,-,F,-,f,s,i,g,1,0,.,p,n,g
# Mask bblais-masks-20240511/2024-05-11-E-F-fsig10.png (applied to average)
#  [#############################100% (ETA: 0.0 s)#############################]
# Norm 0.0,1.0
#  [#############################100% (ETA: 0.0 s)#############################]
# Dog 1,3: 600x800 --> 570x770
#  [#############################100% (ETA: 0.0 s)#############################]
# Saving cache_images/cache_images_2e1a5d81c498f8263dd98928df52128a.asdf...done.
# Actual masks:  b,b,l,a,i,s,-,m,a,s,k,s,-,2,0,2,4,0,5,1,1,/,2,0,2,4,-,0,5,-,1,1,-,E,-,A,-,f,s,i,g,1,0,.,p,n,g
# Mask bblais-masks-20240511/2024-05-11-E-A-fsig10.png (applied to average)
#  [#############################100% (ETA: 0.0 s)#############################]
# Norm 0.0,1.0
#  [#############################100% (ETA: 0.0 s)#############################]
# Dog 1,3: 600x800 --> 570x770
#  [#############################100% (ETA: 0.0 s)#############################]
# Saving cache_images/cache_images_4ddd80e921fd4c2b6ca6e6b9e675b655.asdf...done.
# (-0.5, 769.5, 569.5, -0.5)

# %%
len(image_data['im'])
# Out:
# 118
