# %%
from pylab import *

# %%
from deficit_defs_2025_02_25 import *
# Out:
# Splikes version  0.1.4
# Plasticnet version  0.1.12
# macOS-15.3.2-arm64-arm-64bit
# Base Image File: asdf/bbsk081604_all_scale2.asdf

# %%
mu_c=0
sigma_c=0
mu_r=0
sigma_r=0



base_sim_dir=f"sims-2025-03-13 mu {mu_c} sigma {sigma_c}"
if not os.path.exists(base_sim_dir):
    os.mkdir(base_sim_dir)
print(base_sim_dir)
# Out:
# sims-2025-03-13 mu 0 sigma 0

# %%
number_of_neurons=20
eta=1e-6
number_of_processes=8
ray.init(num_cpus=number_of_processes)
# Out:
# 2025-03-13 14:49:13,429	INFO worker.py:1841 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.12.6', ray_version='2.43.0', ray_commit='ecdcdc6a6e63dc4bcd6ea16aae256ce4d32a7e2c')
# (pid=12351) Splikes version  0.1.4
# (pid=12351) Plasticnet version  0.1.12
# (run_one_deficit_jitter pid=12351) [
# (pid=12358) Splikes version  0.1.4
# (pid=12358) Plasticnet version  0.1.12
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 31.07 s
# (run_one_deficit_jitter pid=12353) [ [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (pid=12353) Splikes version  0.1.4 [repeated 6x across cluster]
# (pid=12353) Plasticnet version  0.1.12 [repeated 6x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.43 s [repeated 8x across cluster]
# (run_one_deficit_jitter pid=12358) [ [repeated 8x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.49 s [repeated 8x across cluster]
# (run_one_deficit_jitter pid=12358) [ [repeated 8x across cluster]
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 32.04 s [repeated 7x across cluster]
# (run_one_deficit_jitter pid=12356) [ [repeated 6x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.46 s
# (run_one_deficit_jitter pid=12358) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 30.64 s
# (run_one_deficit_jitter pid=12354) [ [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 32.00 s [repeated 6x across cluster]
# (run_one_deficit_jitter pid=12358) [ [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.33 s
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 30.39 s
# (run_one_deficit_jitter pid=12354) [ [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12351) .] Sequence Time Elapsed...1 m, 31.32 s [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12358) [ [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.73 s [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12354) [ [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12355) .] Sequence Time Elapsed...1 m, 31.11 s [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12358) [ [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.38 s [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12354) [ [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 30.81 s [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12358) [ [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 32.62 s [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.64 s
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 30.52 s
# (run_one_deficit_jitter pid=12357) [
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 31.31 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12354) [ [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 32.24 s [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12358) [ [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.95 s
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 30.76 s
# (run_one_deficit_jitter pid=12357) [
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 30.94 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12354) [ [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 32.05 s [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12356) [ [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.80 s
# (run_one_deficit_jitter pid=12358) [
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 30.98 s
# (run_one_deficit_jitter pid=12357) [
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 31.34 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12354) [ [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 32.31 s [repeated 4x across cluster]
# (run_one_deficit_jitter pid=12351) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.66 s
# (run_one_deficit_jitter pid=12358) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 30.71 s
# (run_one_deficit_jitter pid=12352) [ [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 30.86 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12355) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12356) .] Sequence Time Elapsed...1 m, 31.53 s [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12358) [ [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.70 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12357) [
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 31.60 s [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12354) [ [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12351) .] Sequence Time Elapsed...1 m, 31.45 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12351) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 32.34 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12358) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.72 s
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 31.23 s
# (run_one_deficit_jitter pid=12352) [ [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12355) .] Sequence Time Elapsed...1 m, 31.02 s [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12355) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12356) .] Sequence Time Elapsed...1 m, 31.33 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12356) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 32.30 s
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.60 s
# (run_one_deficit_jitter pid=12358) [
# (run_one_deficit_jitter pid=12357) [
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 30.90 s [repeated 3x across cluster]
# (run_one_deficit_jitter pid=12352) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12351) .] Sequence Time Elapsed...1 m, 31.27 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12355) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 31.55 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12356) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.83 s
# (run_one_deficit_jitter pid=12358) [
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 31.15 s
# (run_one_deficit_jitter pid=12357) [
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 31.37 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12352) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12355) .] Sequence Time Elapsed...1 m, 32.16 s
# (run_one_deficit_jitter pid=12355) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12351) .] Sequence Time Elapsed...1 m, 31.33 s
# (run_one_deficit_jitter pid=12356) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12356) .] Sequence Time Elapsed...1 m, 32.46 s
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 32.24 s
# (run_one_deficit_jitter pid=12358) [
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 31.29 s
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 31.10 s
# (run_one_deficit_jitter pid=12357) [
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 32.25 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12352) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12351) .] Sequence Time Elapsed...1 m, 31.75 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12354) [
# (run_one_deficit_jitter pid=12355) [
# (run_one_deficit_jitter pid=12356) .] Sequence Time Elapsed...1 m, 32.83 s
# (run_one_deficit_jitter pid=12356) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 32.81 s
# (run_one_deficit_jitter pid=12358) [
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.88 s
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 30.79 s
# (run_one_deficit_jitter pid=12357) [
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 31.19 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12352) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12355) .] Sequence Time Elapsed...1 m, 31.42 s
# (run_one_deficit_jitter pid=12355) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12351) .] Sequence Time Elapsed...1 m, 31.74 s
# (run_one_deficit_jitter pid=12356) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12356) .] Sequence Time Elapsed...1 m, 31.56 s
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 31.91 s
# (run_one_deficit_jitter pid=12358) [
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.80 s
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 30.89 s
# (run_one_deficit_jitter pid=12357) [
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 31.37 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12352) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12355) .] Sequence Time Elapsed...1 m, 31.23 s
# (run_one_deficit_jitter pid=12355) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12351) .] Sequence Time Elapsed...1 m, 31.89 s
# (run_one_deficit_jitter pid=12351) [
# (run_one_deficit_jitter pid=12356) [
# (run_one_deficit_jitter pid=12356) .] Sequence Time Elapsed...1 m, 31.72 s
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 31.97 s
# (run_one_deficit_jitter pid=12358) [
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.76 s
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 30.53 s
# (run_one_deficit_jitter pid=12357) [
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 31.02 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12352) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12355) .] Sequence Time Elapsed...1 m, 30.93 s
# (run_one_deficit_jitter pid=12355) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12351) .] Sequence Time Elapsed...1 m, 31.43 s
# (run_one_deficit_jitter pid=12351) [
# (run_one_deficit_jitter pid=12356) [
# (run_one_deficit_jitter pid=12356) .] Sequence Time Elapsed...1 m, 31.49 s
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 31.57 s
# (run_one_deficit_jitter pid=12358) [
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.33 s
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 30.80 s
# (run_one_deficit_jitter pid=12357) [
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 31.32 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12352) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12355) .] Sequence Time Elapsed...1 m, 32.08 s
# (run_one_deficit_jitter pid=12355) [ [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12351) .] Sequence Time Elapsed...1 m, 31.70 s
# (run_one_deficit_jitter pid=12351) [
# (run_one_deficit_jitter pid=12356) [
# (run_one_deficit_jitter pid=12356) .] Sequence Time Elapsed...1 m, 31.97 s
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 31.87 s
# (run_one_deficit_jitter pid=12358) [
# (run_one_deficit_jitter pid=12357) .] Sequence Time Elapsed...1 m, 30.65 s
# (run_one_deficit_jitter pid=12353) .] Sequence Time Elapsed...1 m, 30.87 s
# (run_one_deficit_jitter pid=12354) .] Sequence Time Elapsed...1 m, 31.65 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12351) .] Sequence Time Elapsed...1 m, 31.88 s [repeated 2x across cluster]
# (run_one_deficit_jitter pid=12358) .] Sequence Time Elapsed...1 m, 31.52 s [repeated 2x across cluster]

# %%
def default_post(number_of_neurons):
    post=pn.neurons.linear_neuron(number_of_neurons)
    post+=pn.neurons.process.sigmoid(0,50)
    return post

def default_bcm(pre,post,orthogonalization=True):
    c=pn.connections.BCM(pre,post,[-.01,.01],[.1,.2])
    
    if orthogonalization:
        c+=pn.connections.process.orthogonalization(10*minute)

    c.eta=2e-6
    c.tau=15*pn.minute   

    return c

# %%
def deficit(blur=[2.5,-1],noise=[0.1,0.1],rf_size=19,
            eta=2e-6,
           number_of_neurons=10,
            mu_c=0,sigma_c=0,    
            mu_r=0,sigma_r=0,
           total_time=8*day,
           save_interval=1*hour):

    
    
    im=[]
    for b in blur:
        if b<0:
            im+=[pi5.filtered_images(base_image_file,
                                    {'type':'norm'},
                                    {'type':'dog','sd1':1,'sd2':3},   
                                    verbose=False,
                                    )
                ]
        else:
            im+=[pi5.filtered_images(base_image_file,
                                    {'type':'blur','size':b},
                                    {'type':'norm'},
                                    {'type':'dog','sd1':1,'sd2':3},   
                                    verbose=False,
                                    )
                ]
    pre1=pn.neurons.natural_images_with_jitter(im[0],
                                   rf_size=rf_size,
                                                sigma_r=0,
                                                sigma_c=0,
                                       verbose=False)

    pre2=pn.neurons.natural_images_with_jitter(im[1],rf_size=rf_size,
                                other_channel=pre1,
                                    mu_r=mu_r,mu_c=mu_c,
                                    sigma_r=sigma_r,sigma_c=sigma_c,
                                verbose=False)

    pre1+=pn.neurons.process.add_noise_normal(0,noise[0])

    sigma=noise
    pre2+=pn.neurons.process.add_noise_normal(0,noise[1])

    pre=pre1+pre2

    post=default_post(number_of_neurons)
    c=default_bcm(pre,post)
    c.eta=eta

    sim=pn.simulation(total_time)
    sim.dt=200*ms

    sim.monitor(post,['output'],save_interval)
    sim.monitor(c,['weights','theta'],save_interval)

    sim+=pn.grating_response(print_time=False,
                        k_mat=linspace(1,20,40)/19.0*pi,
                            )

    return sim,[pre,post],[c]

# %%
@ray.remote
def run_one_deficit_jitter(params,run=True,overwrite=False):
    import plasticnet as pn
    count,eta,noise,blur,mu_c,sigma_c,number_of_neurons,sfname=(params.count,params.eta,params.noise,
                        params.blur,params.mu_c,params.sigma_c,params.number_of_neurons,params.sfname)
    
    if not overwrite and os.path.exists(sfname):
        return sfname
    
    seq=pn.Sequence()
    # deliberately use a standard deficit, with it's own eta and noise
    seq+=deficit(number_of_neurons=params.number_of_neurons,
                 blur=[blur,-1],
                 mu_c=mu_c,sigma_c=sigma_c,
                mu_r=mu_r,sigma_r=sigma_r,) 

    if run:
        seq.run(display_hash=False)
        pn.save(sfname,seq) 
    
    return sfname

# %%
func=func=run_one_deficit_jitter


blur_mat=[0,2,4,6,8,10,12]
open_eye_noise_mat=[0,.1,.2,.3,.4,.5]
mu_c_mat=[0,7,13,21]

sigma_c=0


all_params=[]
for m,mu_c in enumerate(mu_c_mat):
    for b,blur in enumerate(blur_mat):
        for n,noise in enumerate(open_eye_noise_mat):
            sfname=base_sim_dir+f'/deficit {number_of_neurons} neurons noise {noise:.1f} blur {blur:0.1f} mu_c {mu_c:0.1f}.asdf'

            p=Struct()
            p.eta=eta
            p.number_of_neurons=number_of_neurons
            p.sfname=sfname

            p.noise=noise
            p.blur=blur
            p.mu_c=mu_c
            p.sigma_c=sigma_c

            all_params+=[p]

all_params=to_named_tuple(all_params)

# %%
### premake the images
for params in tqdm(all_params):
    result=func.remote(params,run=False,overwrite=True)
    sfname=ray.get(result)
    print(sfname)
# Out:
#   1%|▏                                        | 1/168 [01:11<3:19:11, 71.57s/it]
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 0.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 0.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 0.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 0.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 0.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 0.0 mu_c 0.0.asdf
#   4%|█▊                                         | 7/168 [02:32<52:18, 19.49s/it]
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 2.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 2.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 2.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 2.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 2.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 2.0 mu_c 0.0.asdf
#   8%|███▎                                      | 13/168 [04:21<48:30, 18.78s/it]
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 4.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 4.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 4.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 4.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 4.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 4.0 mu_c 0.0.asdf
#  11%|████▊                                     | 19/168 [07:11<57:17, 23.07s/it]
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 6.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 6.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 6.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 6.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 6.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 6.0 mu_c 0.0.asdf
#  15%|█████▉                                  | 25/168 [11:22<1:12:20, 30.35s/it]
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 8.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 8.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 8.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 8.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 8.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 8.0 mu_c 0.0.asdf
#  18%|███████▍                                | 31/168 [17:16<1:32:34, 40.55s/it]
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 10.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 10.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 10.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 10.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 10.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 10.0 mu_c 0.0.asdf
#  90%|████████████████████████████████████▊    | 151/168 [25:16<01:14,  4.37s/it]
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 12.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 12.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 12.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 12.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 12.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 12.0 mu_c 0.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 0.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 0.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 0.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 0.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 0.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 0.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 2.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 2.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 2.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 2.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 2.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 2.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 4.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 4.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 4.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 4.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 4.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 4.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 6.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 6.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 6.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 6.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 6.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 6.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 8.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 8.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 8.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 8.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 8.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 8.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 10.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 10.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 10.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 10.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 10.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 10.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 12.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 12.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 12.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 12.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 12.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 12.0 mu_c 7.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 0.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 0.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 0.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 0.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 0.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 0.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 2.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 2.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 2.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 2.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 2.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 2.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 4.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 4.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 4.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 4.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 4.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 4.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 6.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 6.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 6.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 6.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 6.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 6.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 8.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 8.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 8.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 8.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 8.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 8.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 10.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 10.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 10.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 10.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 10.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 10.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 12.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 12.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 12.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 12.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 12.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 12.0 mu_c 13.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 0.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 0.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 0.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 0.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 0.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 0.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 2.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 2.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 2.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 2.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 2.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 2.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 4.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 4.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 4.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 4.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 4.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 4.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 6.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 6.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 6.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 6.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 6.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 6.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 8.0 mu_c 21.0.asdf
# 100%|█████████████████████████████████████████| 168/168 [25:16<00:00,  9.02s/it]
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 8.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 8.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 8.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 8.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 8.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 10.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 10.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 10.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 10.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 10.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 10.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 12.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 12.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 12.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 12.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 12.0 mu_c 21.0.asdf
# sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 12.0 mu_c 21.0.asdf

# %%
do_params=make_do_params(all_params,verbose=True)
# Out:
# Doing 168 sims
# [params(eta=1e-06, number_of_neurons=20, sfname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 0.0 mu_c 0.0.asdf', noise=0, blur=0, mu_c=0, sigma_c=0, count=0), params(eta=1e-06, number_of_neurons=20, sfname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 0.0 mu_c 0.0.asdf', noise=0.1, blur=0, mu_c=0, sigma_c=0, count=1), params(eta=1e-06, number_of_neurons=20, sfname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 0.0 mu_c 0.0.asdf', noise=0.2, blur=0, mu_c=0, sigma_c=0, count=2), params(eta=1e-06, number_of_neurons=20, sfname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 0.0 mu_c 0.0.asdf', noise=0.3, blur=0, mu_c=0, sigma_c=0, count=3), params(eta=1e-06, number_of_neurons=20, sfname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 0.0 mu_c 0.0.asdf', noise=0.4, blur=0, mu_c=0, sigma_c=0, count=4)] ... [params(eta=1e-06, number_of_neurons=20, sfname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.1 blur 12.0 mu_c 21.0.asdf', noise=0.1, blur=12, mu_c=21, sigma_c=0, count=163), params(eta=1e-06, number_of_neurons=20, sfname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.2 blur 12.0 mu_c 21.0.asdf', noise=0.2, blur=12, mu_c=21, sigma_c=0, count=164), params(eta=1e-06, number_of_neurons=20, sfname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.3 blur 12.0 mu_c 21.0.asdf', noise=0.3, blur=12, mu_c=21, sigma_c=0, count=165), params(eta=1e-06, number_of_neurons=20, sfname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.4 blur 12.0 mu_c 21.0.asdf', noise=0.4, blur=12, mu_c=21, sigma_c=0, count=166), params(eta=1e-06, number_of_neurons=20, sfname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.5 blur 12.0 mu_c 21.0.asdf', noise=0.5, blur=12, mu_c=21, sigma_c=0, count=167)]

# %%
results = [func.remote(p) for p in do_params]
sfnames=ray.get(results)

# %%
RR={}
for params in tqdm(all_params):
    RR[params.sfname]=Results(params.sfname)
# Out:
# 100%|█████████████████████████████████████████| 168/168 [01:03<00:00,  2.65it/s]

# %%
subResults={}
for params in tqdm(all_params):
    sfname=params.sfname
    R=RR[sfname]
    
    subR=Struct()
    subR.t=R.t/day
    t=subR.t
    
    subR.y=R.y
    subR.θ=R.θ

    #idx1,idx2=[_[1] for _ in R.sequence_index]
    
    subR.ODI=R.ODI
    subR.ORI=R.ORI
    subR.theta_mat=R.theta_mat
    subR.k_mat=R.k_mat
    subR.SF_Var=R.SF_Var
    subR.max_SF=R.max_SF
    subR.sfname=params.sfname
    subR.params=params
    subR.sequence_index=R.sequence_index
    subR.idx=[0]+[_[-1] for _ in R.sequence_index]
    subR.W=R.W[subR.idx,::]
    #subR.recovery_rate=(R.ODI[idx2,:]-R.ODI[idx1,:])/(t[idx2]-t[idx1])
    #subR.SF_Var_recovery_rate=(R.SF_Var[idx2,:]-R.SF_Var[idx1,:])/(t[idx2]-t[idx1])
    #subR.ODI2=R.ODI[idx2,:]
    #subR.ODI1=R.ODI[idx1,:]
    
    subResults[params.sfname]=subR
# Out:
# 100%|█████████████████████████████████████████| 168/168 [00:01<00:00, 91.29it/s]

# %%
# savevars(f'{base_sim_dir}/deficit_results.asdf',
#          'subResults','contrast_result','contrast_mat',
#           'contrast','recovery_rate_μ','recovery_rate_σ',
#             'ODI_μ1','ODI_σ1','ODI_μ2','ODI_σ2',
#           'SF_Var_recovery_rate_μ','SF_Var_recovery_rate_σ')
# Out:
# [(0, 192)]

# %%
subR.SF_Var.shape
# Out:
# (193, 20, 2)

# %%
len(t)
# Out:
# 193

# %%
import plotutils

# %%
fname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 0.0 mu_c 0.0.asdf'

# %%
fname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 0.0 mu_c 0.0.asdf'
subR=subResults[fname]
subplot(2,1,1)
plot(subR.t,subR.y[:,:,0]);

subplot(2,1,2)
plot(subR.t,subR.y[:,:,1]);

# %%
fname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 12.0 mu_c 0.0.asdf'
subR=subResults[fname]
subplot(2,1,1)
plot(subR.t,subR.y[:,:,0]);

subplot(2,1,2)
plot(subR.t,subR.y[:,:,1]);

# %%
fname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 0.0 mu_c 0.0.asdf'
subR=subResults[fname]
subplot(2,1,1)
plot(subR.t,subR.SF_Var[:,:,0]);

subplot(2,1,2)
plot(subR.t,subR.SF_Var[:,:,1]);

# %%
fname='sims-2025-03-13 mu 0 sigma 0/deficit 20 neurons noise 0.0 blur 12.0 mu_c 0.0.asdf'
subR=subResults[fname]
subplot(2,1,1)
plot(subR.t,subR.SF_Var[:,:,0]);

subplot(2,1,2)
plot(subR.t,subR.SF_Var[:,:,1]);

# %%
subR.SF_Var.shape
# Out:
# (193, 20, 2)

# %%
μ,σ=μσ(subR.SF_Var,axis=1)
μ.shape
# Out:
# (193, 2)

# %%
n = 10

colormap=cm.tab10
color = colormap(np.linspace(0, 1,n))


v=np.flip(linspace(0.3,1,len(mu_c_mat)*len(open_eye_noise_mat)))

color_count=0
count=0
h1=[]
h2=[]
labels=[]

sigma_c=0

for m,mu_c in enumerate(mu_c_mat):
    labels+=[f'$\\mu_c={mu_c}$']

    for n,noise in enumerate(open_eye_noise_mat):
    
        St=Storage()
    
        for b,blur in enumerate(blur_mat):
            sfname=base_sim_dir+f'/deficit {number_of_neurons} neurons noise {noise:.1f} blur {blur:0.1f} mu_c {mu_c:0.1f}.asdf'

            subR=subResults[sfname]
            μ,σ=μσ(subR.SF_Var,axis=1)

            St+=blur,μ[-1,0],μ[-1,1],σ[-1,0],σ[-1,1]

        blur,μ1,μ2,σ1,σ2=St.arrays()
        
        h=errorbar(blur,μ1,yerr=2*σ1,marker='o',elinewidth=1,color=cm.Oranges(v[color_count]))
        if n==0:
            h1+=[h[0]]
        h=errorbar(blur,μ2,yerr=2*σ2,marker='s',elinewidth=1,color=cm.Blues(v[color_count]))
        if n==0:
            h2+=[h[0]]
        xlabel('Blur Size [pixels]')
        ylabel('SF Variance')
    
        color_count+=1

# specify the lines and labels of the first legend
ax=gca()
ax.legend(h1, labels,
          loc='upper left', frameon=False,fontsize=15)

#text(0,5,'Amblyopic',color=cm.Oranges(v[1]))

# # Create the second legend and add the artist manually.
from matplotlib.legend import Legend
leg = Legend(ax, h2, labels,
              loc='upper center', frameon=False,fontsize=15)
ax.add_artist(leg)
#text(7,40,'Fellow',color=cm.Blues(v[1]))

# %%
n = 10

colormap=cm.tab10
color = colormap(np.linspace(0, 1,n))


v=np.flip(linspace(0.3,1,4))

color_count=0
count=0
h1=[]
h2=[]
labels=[]
for mu_count,mu_c in enumerate(mu_c_mat):
    for sigma_count,sigma_c in enumerate(sigma_c_mat):
        
        labels+=[f'$\mu_c={mu_c}$,$\sigma_c={sigma_c}$']
        
        s=Storage()
        for blur_count,blur in enumerate(blur_mat):


            params=all_params[count]
            count+=1

            R=RR[params.sfname]

            blur=params.blur
            μ1,μ2=R.μσ[0][0]
            σ1,σ2=R.μσ[1][0]

            s+=blur,μ1,μ2,σ1,σ2

        blur,μ1,μ2,σ1,σ2=s.arrays()
        h=errorbar(blur,μ1,yerr=2*σ1,marker='o',elinewidth=1,color=cm.Oranges(v[color_count]))
        h1+=[h[0]]
        h=errorbar(blur,μ2,yerr=2*σ2,marker='s',elinewidth=1,color=cm.Blues(v[color_count]))
        h2+=[h[0]]
        xlabel('Blur Size [pixels]')
        ylabel('Maximum Response')
        
        color_count+=1


# specify the lines and labels of the first legend
ax=gca()
ax.legend(h1, labels,
          loc='lower left', frameon=False,fontsize=15)

text(0,5,'Amblyopic',color=cm.Oranges(v[1]))

# # Create the second legend and add the artist manually.
from matplotlib.legend import Legend
leg = Legend(ax, h2, labels,
              loc='upper right', frameon=False,fontsize=15)
ax.add_artist(leg)
text(7,40,'Fellow',color=cm.Blues(v[1]))
