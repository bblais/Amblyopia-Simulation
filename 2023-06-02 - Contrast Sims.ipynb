# %%
# %matplotlib inline
from pylab import *
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
from treatment_sims_2023_06_02 import *
# Out:
# Splikes version  0.1.2
# Plasticnet version  0.1.9
# macOS-10.16-x86_64-i386-64bit

# %%
base='sims/2023-06-02'
if not os.path.exists(base):
    print(f"mkdir {base}")
    os.mkdir(base)

# %% [markdown]
# ## Just do the contrast with no jitter

# %%
rf_size=19
eta=1e-6
number_of_neurons=25
number_of_processes=4
mu_c=0
sigma_c=0
blur=4
open_eye_noise=0.1

mu_c_mat=[0,7.5,0,7.5]
sigma_c_mat=[0,2,2,0]
contrast_mat=linspace(0,1,21)  # linspace(0,1,11)
mask_mat=array([0,1])
f_mat=array([10,30,50,70,90])


contrast_mat
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])

# %%
from collections import namedtuple


params = namedtuple('params', ['count', 'eta','blur','contrast','f','mask','number_of_neurons','sfname','mu_c','sigma_c'])
all_params=[]
count=0


for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    for mask in mask_mat:
        if mask:
            for fc,f in enumerate(f_mat):
                for contrast_count,contrast in enumerate(contrast_mat):
                    all_params.append(params(count=count,
                                 eta=eta,
                                     blur=blur,
                                             contrast=contrast,
                                             f=f,
                                             mask=mask,
                                 number_of_neurons=number_of_neurons,
                                sfname=f'{base}/contrast mask {number_of_neurons} neurons {mu_c} mu_c {sigma_c} sigma_c {blur} blur {contrast:.2f} contrast {mask} mask {f} f.asdf',
                                mu_c=mu_c,sigma_c=sigma_c))

                    count+=1

        else:
            f=10
            for contrast_count,contrast in enumerate(contrast_mat):
                all_params.append(params(count=count,
                             eta=eta,
                                 blur=blur,
                                         contrast=contrast,
                                         f=f,
                                         mask=mask,
                             number_of_neurons=number_of_neurons,
                            sfname=f'{base}/contrast mask {number_of_neurons} neurons {mu_c} mu_c {sigma_c} sigma_c {blur} blur {contrast:.2f} contrast {mask} mask {f} f.asdf',
                            mu_c=mu_c,sigma_c=sigma_c))

                count+=1



for a in all_params[:5]:
    print(a)
print("[....]")
for a in all_params[-5:]:
    print(a)

print(len(all_params))
# Out:
# params(count=0, eta=1e-06, blur=4, contrast=0.0, f=10, mask=0, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 0 mu_c 0 sigma_c 4 blur 0.00 contrast 0 mask 10 f.asdf', mu_c=0, sigma_c=0)
# params(count=1, eta=1e-06, blur=4, contrast=0.05, f=10, mask=0, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 0 mu_c 0 sigma_c 4 blur 0.05 contrast 0 mask 10 f.asdf', mu_c=0, sigma_c=0)
# params(count=2, eta=1e-06, blur=4, contrast=0.1, f=10, mask=0, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 0 mu_c 0 sigma_c 4 blur 0.10 contrast 0 mask 10 f.asdf', mu_c=0, sigma_c=0)
# params(count=3, eta=1e-06, blur=4, contrast=0.15000000000000002, f=10, mask=0, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 0 mu_c 0 sigma_c 4 blur 0.15 contrast 0 mask 10 f.asdf', mu_c=0, sigma_c=0)
# params(count=4, eta=1e-06, blur=4, contrast=0.2, f=10, mask=0, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 0 mu_c 0 sigma_c 4 blur 0.20 contrast 0 mask 10 f.asdf', mu_c=0, sigma_c=0)
# [....]
# params(count=499, eta=1e-06, blur=4, contrast=0.8, f=90, mask=1, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.80 contrast 1 mask 90 f.asdf', mu_c=7.5, sigma_c=0)
# params(count=500, eta=1e-06, blur=4, contrast=0.8500000000000001, f=90, mask=1, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.85 contrast 1 mask 90 f.asdf', mu_c=7.5, sigma_c=0)
# params(count=501, eta=1e-06, blur=4, contrast=0.9, f=90, mask=1, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.90 contrast 1 mask 90 f.asdf', mu_c=7.5, sigma_c=0)
# params(count=502, eta=1e-06, blur=4, contrast=0.9500000000000001, f=90, mask=1, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.95 contrast 1 mask 90 f.asdf', mu_c=7.5, sigma_c=0)
# params(count=503, eta=1e-06, blur=4, contrast=1.0, f=90, mask=1, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 7.5 mu_c 0 sigma_c 4 blur 1.00 contrast 1 mask 90 f.asdf', mu_c=7.5, sigma_c=0)
# 504

# %%
blur
# Out:
# 4

# %% [markdown]
# ## Functions for contrast mask

# %%
def run_one_continuous_mask_jitter(params,
                                    overwrite=False,
                                 run=True):
    import plasticnet as pn
    count,eta,blur,contrast,mask,f,mu_c,sigma_c,number_of_neurons,sfname=(params.count,params.eta,params.blur,params.contrast,params.mask,params.f,
                                        params.mu_c,params.sigma_c,params.number_of_neurons,params.sfname)
    
    
    if os.path.exists(sfname):
        if not overwrite:
            return sfname
        else:
            os.remove(sfname)

    
    seq=pn.Sequence()
    deficit_base_sim=f'{base}/deficit {number_of_neurons} neurons {mu_c} mu_c {sigma_c} sigma_c {blur} blur.asdf'

    seq+=treatment_jitter(f=f,
                   mask=mask,
                   contrast=contrast,
                   total_time=8*day,
                   eta=eta,
                          number_of_neurons=number_of_neurons,
                    mu_c=mu_c,sigma_c=sigma_c,
                   save_interval=20*minute)

    if run:
        
        seq_load(seq,deficit_base_sim)    
        
        seq.run(display_hash=False)
        pn.save(sfname,seq) 

    
    return sfname

# %%
func=run_one_continuous_mask_jitter

# %% [markdown]
# ## Premake the image files

# %%
base_image_file='asdf/bbsk081604_all_scale2.asdf'
print("Base Image File:",base_image_file)


# somehow calling these functions breaks the multiprocessing?
# Process ForkPoolWorker-1:
#_pickle.UnpicklingError: NEWOBJ class argument isn't a type object


# so run this, then restart kernel, and then skip this cell
# until I can figure out why this does this
for params in all_params:
    func(params,overwrite=False,run=False)
# Out:
#  [#############################100% (ETA: 0.0 s)#############################]
# Resolution float64 -> uint16

# %%
params
# Out:
# params(count=503, eta=1e-06, blur=4, contrast=1.0, f=90, mask=1, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 7.5 mu_c 0 sigma_c 4 blur 1.00 contrast 1 mask 90 f.asdf', mu_c=7.5, sigma_c=0)

# %%
len(all_params)
# Out:
# 504

# %% [markdown]
# ## Run the sims

# %%
do_params=make_do_params(all_params)
len(do_params)
# Out:
# 0

# %%
# %%time
print(func.__name__)
func(all_params[0],overwrite=True)
# Out:
# run_one_continuous_mask_jitter
# [.] Sequence Time Elapsed...4 m, 53.64 s
# CPU times: user 4min 58s, sys: 3.21 s, total: 5min 1s
# Wall time: 5min 2s
# 'sims/2023-06-02/contrast mask 25 neurons 0 mu_c 0 sigma_c 4 blur 0.00 contrast 0 mask 10 f.asdf'

# %%
real_time=5*60+ 51

# %%
if len(do_params)>13:
    for a in do_params[:5]:
        print(a)
    print("[....]")
    for a in do_params[-5:]:
        print(a)
else:
    for a in do_params:
        print(a)
    

print(len(do_params))

print(time2str(real_time*len(do_params)/number_of_processes))
# Out:
# params(count=0, eta=1e-06, blur=4, contrast=0.0, f=10, mask=0, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 0 mu_c 0 sigma_c 4 blur 0.00 contrast 0 mask 10 f.asdf', mu_c=0, sigma_c=0)
# params(count=1, eta=1e-06, blur=4, contrast=0.05, f=10, mask=0, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 0 mu_c 0 sigma_c 4 blur 0.05 contrast 0 mask 10 f.asdf', mu_c=0, sigma_c=0)
# params(count=2, eta=1e-06, blur=4, contrast=0.1, f=10, mask=0, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 0 mu_c 0 sigma_c 4 blur 0.10 contrast 0 mask 10 f.asdf', mu_c=0, sigma_c=0)
# params(count=3, eta=1e-06, blur=4, contrast=0.15000000000000002, f=10, mask=0, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 0 mu_c 0 sigma_c 4 blur 0.15 contrast 0 mask 10 f.asdf', mu_c=0, sigma_c=0)
# params(count=4, eta=1e-06, blur=4, contrast=0.2, f=10, mask=0, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 0 mu_c 0 sigma_c 4 blur 0.20 contrast 0 mask 10 f.asdf', mu_c=0, sigma_c=0)
# [....]
# params(count=499, eta=1e-06, blur=4, contrast=0.8, f=90, mask=1, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.80 contrast 1 mask 90 f.asdf', mu_c=7.5, sigma_c=0)
# params(count=500, eta=1e-06, blur=4, contrast=0.8500000000000001, f=90, mask=1, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.85 contrast 1 mask 90 f.asdf', mu_c=7.5, sigma_c=0)
# params(count=501, eta=1e-06, blur=4, contrast=0.9, f=90, mask=1, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.90 contrast 1 mask 90 f.asdf', mu_c=7.5, sigma_c=0)
# params(count=502, eta=1e-06, blur=4, contrast=0.9500000000000001, f=90, mask=1, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 7.5 mu_c 0 sigma_c 4 blur 0.95 contrast 1 mask 90 f.asdf', mu_c=7.5, sigma_c=0)
# params(count=503, eta=1e-06, blur=4, contrast=1.0, f=90, mask=1, number_of_neurons=25, sfname='sims/2023-06-02/contrast mask 25 neurons 7.5 mu_c 0 sigma_c 4 blur 1.00 contrast 1 mask 90 f.asdf', mu_c=7.5, sigma_c=0)
# 504
# 12 h, 17 m, 6.00 s

# %%
if do_params:
    pool = Pool(processes=number_of_processes)
    async_results = [pool.apply_async(func, args=(p,),kwds={'overwrite':False,'run':True}) 
                             for p in do_params]
    results =[_.get() for _ in async_results]
    
results
# Out:
# [[[[.] Sequence Time Elapsed...7 m, 31.96 s
# .] Sequence Time Elapsed...7 m, 32.65 s
# .] Sequence Time Elapsed...7 m, 33.04 s
# .] Sequence Time Elapsed...7 m, 33.76 s
# [[[[.] Sequence Time Elapsed...7 m, 41.70 s
# .] Sequence Time Elapsed...7 m, 41.88 s
# .] Sequence Time Elapsed...7 m, 44.62 s
# .] Sequence Time Elapsed...7 m, 44.96 s
# [[[[.] Sequence Time Elapsed...7 m, 44.76 s
# .] Sequence Time Elapsed...7 m, 46.08 s
# .] Sequence Time Elapsed...7 m, 44.62 s
# .] Sequence Time Elapsed...7 m, 45.19 s
# [[[[.] Sequence Time Elapsed...7 m, 40.18 s
# .] Sequence Time Elapsed...7 m, 42.18 s
# .] Sequence Time Elapsed...7 m, 42.66 s
# .] Sequence Time Elapsed...7 m, 41.14 s
# [[[[.] Sequence Time Elapsed...7 m, 37.78 s
# .] Sequence Time Elapsed...7 m, 38.17 s
# .] Sequence Time Elapsed...7 m, 38.36 s
# .] Sequence Time Elapsed...7 m, 40.26 s
# [[[[.] Sequence Time Elapsed...7 m, 40.02 s
# .] Sequence Time Elapsed...7 m, 40.51 s
# .] Sequence Time Elapsed...7 m, 40.53 s
# .] Sequence Time Elapsed...7 m, 40.35 s
# [[[[.] Sequence Time Elapsed...7 m, 36.68 s
# .] Sequence Time Elapsed...7 m, 37.24 s
# .] Sequence Time Elapsed...7 m, 37.50 s
# .] Sequence Time Elapsed...7 m, 35.86 s
# [[[[.] Sequence Time Elapsed...8 m, 2.66 s
# .] Sequence Time Elapsed...8 m, 6.55 s
# .] Sequence Time Elapsed...8 m, 7.30 s
# .] Sequence Time Elapsed...8 m, 8.73 s
# [[[[.] Sequence Time Elapsed...7 m, 53.29 s
# .] Sequence Time Elapsed...7 m, 55.95 s
# .] Sequence Time Elapsed...7 m, 54.85 s
# .] Sequence Time Elapsed...7 m, 51.69 s
# [[[[.] Sequence Time Elapsed...7 m, 41.06 s
# .] Sequence Time Elapsed...7 m, 41.18 s
# .] Sequence Time Elapsed...7 m, 42.45 s
# .] Sequence Time Elapsed...7 m, 43.40 s
# [[[[.] Sequence Time Elapsed...6 m, 49.00 s
# .] Sequence Time Elapsed...6 m, 52.75 s
# .] Sequence Time Elapsed...6 m, 53.41 s
# .] Sequence Time Elapsed...6 m, 54.73 s
# [[[[.] Sequence Time Elapsed...6 m, 37.24 s
# .] Sequence Time Elapsed...6 m, 38.73 s
# .] .Sequence Time Elapsed...6 m, 39.28 s
# ] Sequence Time Elapsed...6 m, 38.72 s
# [[[[.] Sequence Time Elapsed...6 m, 30.98 s
# .] Sequence Time Elapsed...6 m, 31.41 s
# .] Sequence Time Elapsed...6 m, 29.60 s
# .] Sequence Time Elapsed...6 m, 30.51 s
# [[[[.] Sequence Time Elapsed...6 m, 32.98 s
# .] Sequence Time Elapsed...6 m, 34.34 s
# .] Sequence Time Elapsed...6 m, 34.22 s
# .] Sequence Time Elapsed...6 m, 33.25 s
# [[[[.] Sequence Time Elapsed...6 m, 23.99 s
# [.] Sequence Time Elapsed...6 m, 29.65 s
# .] Sequence Time Elapsed...6 m, 29.51 s
# .] Sequence Time Elapsed...6 m, 29.74 s
# [[[.] Sequence Time Elapsed...5 m, 57.56 s
# [.] Sequence Time Elapsed...6 m, 4.26 s
# .] Sequence Time Elapsed...6 m, 5.73 s
# .] Sequence Time Elapsed...6 m, 7.38 s
# [[[.] Sequence Time Elapsed...5 m, 55.35 s
# [.] Sequence Time Elapsed...5 m, 54.18 s
# .] Sequence Time Elapsed...5 m, 54.27 s
# .] Sequence Time Elapsed...5 m, 54.71 s
# [[[.] Sequence Time Elapsed...5 m, 54.15 s
# [.] Sequence Time Elapsed...5 m, 49.25 s
# .] Sequence Time Elapsed...5 m, 48.17 s
# .] Sequence Time Elapsed...5 m, 48.27 s
# [[[.] Sequence Time Elapsed...6 m, 8.76 s
# [.] Sequence Time Elapsed...6 m, 7.01 s
# .] Sequence Time Elapsed...6 m, 5.65 s
# .] Sequence Time Elapsed...6 m, 4.55 s
# [[[.] Sequence Time Elapsed...6 m, 24.56 s
# .] Sequence Time Elapsed...6 m, 21.38 s
# .] Sequence Time Elapsed...6 m, 22.21 s
# [.] Sequence Time Elapsed...6 m, 22.40 s
# [[[.] Sequence Time Elapsed...6 m, 27.77 s
# .] Sequence Time Elapsed...6 m, 24.46 s
# [.] Sequence Time Elapsed...6 m, 25.71 s
# .] Sequence Time Elapsed...6 m, 24.65 s
# [[[.] Sequence Time Elapsed...6 m, 40.66 s
# [.] Sequence Time Elapsed...6 m, 42.68 s
# .] Sequence Time Elapsed...6 m, 42.07 s
# .] Sequence Time Elapsed...6 m, 43.05 s
# [[[.] Sequence Time Elapsed...4 m, 24.31 s
# .] Sequence Time Elapsed...4 m, 22.08 s
# [.] Sequence Time Elapsed...4 m, 21.69 s
# .] Sequence Time Elapsed...4 m, 21.75 s
# [[[.] Sequence Time Elapsed...4 m, 1.65 s
# [.] Sequence Time Elapsed...4 m, 0.55 s
# .] Sequence Time Elapsed...4 m, 0.10 s
# .] Sequence Time Elapsed...4 m, 1.60 s
# [[[.] Sequence Time Elapsed...4 m, 1.17 s
# .] Sequence Time Elapsed...3 m, 58.77 s
# [.] Sequence Time Elapsed...3 m, 59.92 s
# .] Sequence Time Elapsed...4 m, 0.38 s
# [[[.] Sequence Time Elapsed...3 m, 59.19 s
# .] Sequence Time Elapsed...3 m, 59.98 s
# [.] Sequence Time Elapsed...4 m, 0.31 s
# .] Sequence Time Elapsed...3 m, 58.98 s
# [[[.] Sequence Time Elapsed...3 m, 58.60 s
# .] Sequence Time Elapsed...3 m, 58.22 s
# [.] Sequence Time Elapsed...3 m, 56.97 s
# .] Sequence Time Elapsed...3 m, 57.93 s
# [[[.] Sequence Time Elapsed...3 m, 58.62 s
# .] Sequence Time Elapsed...3 m, 58.29 s
# [.] Sequence Time Elapsed...3 m, 58.38 s
# .] Sequence Time Elapsed...3 m, 58.82 s
# [[[.] Sequence Time Elapsed...3 m, 57.50 s
# .] Sequence Time Elapsed...3 m, 57.96 s
# [.] Sequence Time Elapsed...3 m, 57.22 s
# .] Sequence Time Elapsed...3 m, 56.07 s
# [[[.] Sequence Time Elapsed...3 m, 58.42 s
# .] Sequence Time Elapsed...3 m, 57.89 s
# .] Sequence Time Elapsed...3 m, 56.78 s
# [.] Sequence Time Elapsed...3 m, 58.56 s
# [[[.] Sequence Time Elapsed...3 m, 56.87 s
# .] Sequence Time Elapsed...3 m, 57.61 s
# .] Sequence Time Elapsed...3 m, 56.98 s
# [.] Sequence Time Elapsed...3 m, 56.88 s
# [[[.] Sequence Time Elapsed...3 m, 56.69 s
# .] Sequence Time Elapsed...3 m, 55.25 s
# .] Sequence Time Elapsed...3 m, 55.51 s
# [.] Sequence Time Elapsed...3 m, 54.42 s
# [[[.] Sequence Time Elapsed...3 m, 55.61 s
# .] Sequence Time Elapsed...3 m, 54.03 s
# .] Sequence Time Elapsed...3 m, 54.67 s
# [.] Sequence Time Elapsed...3 m, 54.97 s
# [[[.] Sequence Time Elapsed...3 m, 56.55 s
# .] Sequence Time Elapsed...3 m, 56.31 s
# .] Sequence Time Elapsed...3 m, 56.70 s
# [[.] Sequence Time Elapsed...3 m, 56.43 s
# [[.] Sequence Time Elapsed...4 m, 5.87 s
# .] Sequence Time Elapsed...4 m, 3.90 s
# .] Sequence Time Elapsed...4 m, 3.22 s
# [[[.] Sequence Time Elapsed...4 m, 4.03 s
# [.] Sequence Time Elapsed...3 m, 56.89 s
# .] Sequence Time Elapsed...3 m, 56.50 s
# .] Sequence Time Elapsed...3 m, 55.96 s
# [[[.] Sequence Time Elapsed...3 m, 57.41 s
# [.] Sequence Time Elapsed...3 m, 57.65 s
# .] Sequence Time Elapsed...3 m, 56.48 s
# .] Sequence Time Elapsed...3 m, 55.98 s
# [[[.] Sequence Time Elapsed...3 m, 56.84 s
# [.] Sequence Time Elapsed...3 m, 55.72 s
# .] Sequence Time Elapsed...3 m, 55.24 s
# .] Sequence Time Elapsed...3 m, 55.83 s
# [[[.] Sequence Time Elapsed...3 m, 55.71 s
# [.] Sequence Time Elapsed...3 m, 54.96 s
# .] Sequence Time Elapsed...3 m, 54.06 s
# .] Sequence Time Elapsed...3 m, 55.55 s
# [[[.] Sequence Time Elapsed...3 m, 54.20 s
# [.] Sequence Time Elapsed...3 m, 55.42 s
# .] Sequence Time Elapsed...3 m, 54.73 s
# .] Sequence Time Elapsed...3 m, 55.54 s
# [[[.] Sequence Time Elapsed...3 m, 54.82 s
# [.] Sequence Time Elapsed...3 m, 55.28 s
# .] Sequence Time Elapsed...3 m, 54.62 s
# .] Sequence Time Elapsed...3 m, 55.37 s
# [[[.] Sequence Time Elapsed...3 m, 55.30 s
# [.] Sequence Time Elapsed...3 m, 53.98 s
# .] Sequence Time Elapsed...3 m, 55.47 s
# .] Sequence Time Elapsed...3 m, 54.36 s
# [[[.] Sequence Time Elapsed...3 m, 55.03 s
# [.] Sequence Time Elapsed...3 m, 54.91 s
# .] Sequence Time Elapsed...3 m, 54.31 s
# .] Sequence Time Elapsed...3 m, 53.54 s
# [[[.] Sequence Time Elapsed...3 m, 54.70 s
# [.] Sequence Time Elapsed...3 m, 55.37 s
# .] Sequence Time Elapsed...3 m, 54.12 s
# .] Sequence Time Elapsed...3 m, 54.82 s
# [[[.] Sequence Time Elapsed...3 m, 54.90 s
# [.] Sequence Time Elapsed...3 m, 53.71 s
# .] Sequence Time Elapsed...3 m, 54.42 s
# .] Sequence Time Elapsed...3 m, 55.21 s
# [[[.] Sequence Time Elapsed...3 m, 55.90 s
# [.] Sequence Time Elapsed...3 m, 53.50 s
# .] Sequence Time Elapsed...3 m, 53.72 s
# .] Sequence Time Elapsed...3 m, 54.23 s
# [[[.] Sequence Time Elapsed...3 m, 53.76 s
# [.] Sequence Time Elapsed...3 m, 55.63 s
# .] Sequence Time Elapsed...3 m, 55.96 s
# .] Sequence Time Elapsed...3 m, 55.85 s
# [[[.] Sequence Time Elapsed...3 m, 56.23 s
# [.] Sequence Time Elapsed...3 m, 54.39 s
# .] Sequence Time Elapsed...3 m, 54.90 s
# .] Sequence Time Elapsed...3 m, 54.19 s
# [[[.] Sequence Time Elapsed...3 m, 53.89 s
# [.] Sequence Time Elapsed...3 m, 55.70 s
# .] Sequence Time Elapsed...3 m, 55.90 s
# .] Sequence Time Elapsed...3 m, 55.11 s
# [[[.] Sequence Time Elapsed...3 m, 53.11 s
# [.] Sequence Time Elapsed...3 m, 55.47 s
# .] Sequence Time Elapsed...3 m, 55.70 s
# .] Sequence Time Elapsed...3 m, 56.18 s
# [[[.] Sequence Time Elapsed...3 m, 53.26 s
# [.] Sequence Time Elapsed...3 m, 55.66 s
# .] Sequence Time Elapsed...3 m, 56.23 s
# .] Sequence Time Elapsed...3 m, 56.46 s
# [[.] Sequence Time Elapsed...3 m, 54.37 s
# [[.] Sequence Time Elapsed...3 m, 55.17 s
# .] Sequence Time Elapsed...3 m, 55.21 s
# .] Sequence Time Elapsed...3 m, 55.59 s
# [.] Sequence Time Elapsed...3 m, 54.59 s
# [[[.] Sequence Time Elapsed...3 m, 55.04 s
# .] Sequence Time Elapsed...3 m, 56.11 s
# .] Sequence Time Elapsed...3 m, 55.96 s
# [.] Sequence Time Elapsed...3 m, 54.53 s
# [[[.] Sequence Time Elapsed...3 m, 55.10 s
# .] Sequence Time Elapsed...3 m, 54.52 s
# .] Sequence Time Elapsed...3 m, 54.93 s
# .] Sequence Time Elapsed...3 m, 54.33 s
# [[[[.] Sequence Time Elapsed...3 m, 54.81 s
# .] Sequence Time Elapsed...3 m, 54.59 s
# .] Sequence Time Elapsed...3 m, 54.06 s
# .] Sequence Time Elapsed...3 m, 54.61 s
# [[[[.] Sequence Time Elapsed...3 m, 55.10 s
# .] Sequence Time Elapsed...3 m, 54.82 s
# .] Sequence Time Elapsed...3 m, 54.75 s
# .] Sequence Time Elapsed...3 m, 53.45 s
# [[[[.] Sequence Time Elapsed...3 m, 53.98 s
# .] Sequence Time Elapsed...3 m, 53.76 s
# .] Sequence Time Elapsed...3 m, 54.83 s
# .] Sequence Time Elapsed...3 m, 54.23 s
# [[[[.] Sequence Time Elapsed...3 m, 53.61 s
# .] Sequence Time Elapsed...3 m, 53.53 s
# .] Sequence Time Elapsed...3 m, 54.24 s
# .] Sequence Time Elapsed...3 m, 52.90 s
# [[[[.] Sequence Time Elapsed...3 m, 53.97 s
# .] Sequence Time Elapsed...3 m, 53.86 s
# .] Sequence Time Elapsed...3 m, 53.74 s
# .] Sequence Time Elapsed...3 m, 52.97 s
# [[[[.] Sequence Time Elapsed...3 m, 54.84 s
# .] Sequence Time Elapsed...3 m, 54.14 s
# .] Sequence Time Elapsed...3 m, 55.42 s
# .] Sequence Time Elapsed...3 m, 53.56 s
# [[[[.] Sequence Time Elapsed...3 m, 53.08 s
# .] Sequence Time Elapsed...3 m, 54.73 s
# .] Sequence Time Elapsed...3 m, 53.72 s
# .] Sequence Time Elapsed...3 m, 54.11 s
# [[[[.] Sequence Time Elapsed...3 m, 53.22 s
# .] Sequence Time Elapsed...3 m, 54.00 s
# .] Sequence Time Elapsed...3 m, 53.61 s
# .] Sequence Time Elapsed...3 m, 54.74 s
# [[[[.] Sequence Time Elapsed...3 m, 53.60 s
# .] Sequence Time Elapsed...3 m, 53.46 s
# .] Sequence Time Elapsed...3 m, 53.89 s
# .] Sequence Time Elapsed...3 m, 54.32 s
# [[[[.] Sequence Time Elapsed...3 m, 53.76 s
# .] Sequence Time Elapsed...3 m, 54.00 s
# .] Sequence Time Elapsed...3 m, 53.40 s
# .] Sequence Time Elapsed...3 m, 53.74 s
# [[[[.] Sequence Time Elapsed...3 m, 56.56 s
# .] Sequence Time Elapsed...3 m, 56.73 s
# .] Sequence Time Elapsed...3 m, 56.57 s
# .] Sequence Time Elapsed...3 m, 55.61 s
# [[[[.] Sequence Time Elapsed...3 m, 58.47 s
# .] Sequence Time Elapsed...3 m, 58.35 s
# .] Sequence Time Elapsed...3 m, 59.56 s
# .] Sequence Time Elapsed...3 m, 58.68 s
# [[[[.] Sequence Time Elapsed...3 m, 54.93 s
# .] Sequence Time Elapsed...3 m, 54.29 s
# .] Sequence Time Elapsed...3 m, 55.13 s
# .] Sequence Time Elapsed...3 m, 53.35 s
# [[[[.] Sequence Time Elapsed...3 m, 52.97 s
# .] Sequence Time Elapsed...3 m, 53.11 s
# .] Sequence Time Elapsed...3 m, 55.29 s
# .] Sequence Time Elapsed...3 m, 52.42 s
# [[[[.] Sequence Time Elapsed...3 m, 53.55 s
# .] Sequence Time Elapsed...3 m, 52.89 s
# .] Sequence Time Elapsed...3 m, 52.58 s
# .] Sequence Time Elapsed...3 m, 53.31 s
# [[[[.] Sequence Time Elapsed...3 m, 53.51 s
# .] Sequence Time Elapsed...3 m, 54.00 s
# .] Sequence Time Elapsed...3 m, 52.97 s
# .] Sequence Time Elapsed...3 m, 54.04 s
# [[[[.] Sequence Time Elapsed...3 m, 55.61 s
# .] Sequence Time Elapsed...3 m, 55.18 s
# .] Sequence Time Elapsed...3 m, 55.27 s
# .] Sequence Time Elapsed...3 m, 55.32 s
# [[[[.] Sequence Time Elapsed...3 m, 53.43 s
# .] Sequence Time Elapsed...3 m, 53.31 s
# .] Sequence Time Elapsed...3 m, 54.15 s
# .] Sequence Time Elapsed...3 m, 52.70 s
# [[[[.] Sequence Time Elapsed...3 m, 52.42 s
# .] Sequence Time Elapsed...3 m, 51.93 s
# .] Sequence Time Elapsed...3 m, 52.27 s
# .] Sequence Time Elapsed...3 m, 52.66 s
# [[[[.] Sequence Time Elapsed...3 m, 54.21 s
# .] Sequence Time Elapsed...3 m, 53.18 s
# .] Sequence Time Elapsed...3 m, 53.61 s
# .] Sequence Time Elapsed...3 m, 53.60 s
# [[[[.] Sequence Time Elapsed...3 m, 53.91 s
# .] Sequence Time Elapsed...3 m, 54.25 s
# .] Sequence Time Elapsed...3 m, 54.15 s
# .] Sequence Time Elapsed...3 m, 54.15 s
# [[[[.] Sequence Time Elapsed...3 m, 52.91 s
# .] Sequence Time Elapsed...3 m, 51.87 s
# .] Sequence Time Elapsed...3 m, 51.68 s
# .] Sequence Time Elapsed...3 m, 52.55 s
# [[[[.] Sequence Time Elapsed...3 m, 55.31 s
# .] Sequence Time Elapsed...3 m, 54.84 s
# .] Sequence Time Elapsed...3 m, 53.19 s
# .] Sequence Time Elapsed...3 m, 53.47 s
# [[[[.] Sequence Time Elapsed...3 m, 54.49 s
# .] Sequence Time Elapsed...3 m, 54.62 s
# .] Sequence Time Elapsed...3 m, 55.61 s
# .] Sequence Time Elapsed...3 m, 54.95 s
# [[[[.] Sequence Time Elapsed...3 m, 54.28 s
# .] Sequence Time Elapsed...3 m, 55.28 s
# .] Sequence Time Elapsed...3 m, 55.00 s
# .] Sequence Time Elapsed...3 m, 53.88 s
# [[[[.] Sequence Time Elapsed...3 m, 54.60 s
# .] Sequence Time Elapsed...3 m, 54.57 s
# .] Sequence Time Elapsed...3 m, 55.91 s
# .] Sequence Time Elapsed...3 m, 54.53 s
# [[[[.] Sequence Time Elapsed...3 m, 52.78 s
# .] Sequence Time Elapsed...3 m, 52.84 s
# .] Sequence Time Elapsed...3 m, 53.56 s
# .] Sequence Time Elapsed...3 m, 54.85 s
# [[[[

# %% [markdown]
# ## View the sims

# %%
sfname=all_params[0].sfname
R=Results(sfname)

# %%
t,y,θ,W=R[-1]
vmin=W.min()
vmax=W.max()

w_im=R.weight_image(W)
count=1
for n in range(4):
    for c in range(2):
        subplot(4,2,count)
        pcolormesh(w_im[n,c,...],cmap=py.cm.gray,
                        vmin=vmin,vmax=vmax)
        ax2=gca()
        ax2.set_aspect('equal')
        ax2.set_xticklabels([])
        ax2.set_yticklabels([])
        ax2.xaxis.set_ticks_position('none') 
        ax2.yaxis.set_ticks_position('none') 
        
        count+=1
# Out:
# /Users/bblais/tmp/ipykernel_1264/1582112873.py:10: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   pcolormesh(w_im[n,c,...],cmap=py.cm.gray,

# %%
# RR={}
# count=0
# for params in tqdm(all_params):
#     RR[params.sfname]=Results(params.sfname)

# %% [markdown]
# ![image.png](attachment:53d620ef-06e0-4995-a4a5-a90881f48619.png)

# %%
count=0

v=np.flip(linspace(0.3,1,len(f_mat)))

figcount=0
for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    figure()
    for mask in mask_mat:
        if mask:
            for fc,f in tqdm(enumerate(f_mat),total=len(f_mat)):
                s=Storage()
                for contrast_count,contrast in tqdm(enumerate(contrast_mat),total=len(contrast_mat)):

                    params=all_params[count]
                    count+=1
                    R=Results(params.sfname)
                    #R=RR[params.sfname]
                    contrast=params.contrast
                    μ1,μ2=R.μσ[0][0]
                    σ1,σ2=R.μσ[1][0]

                    s+=contrast,μ1,μ2,σ1,σ2
                    
                contrast,μ1,μ2,σ1,σ2=s.arrays()

                
                if fc==1:
                    errorbar(contrast,μ1,yerr=2*σ1,marker='o',elinewidth=1,label=f'Amblyopic',color=cm.Blues(v[fc]))
                    errorbar(contrast,μ2,yerr=2*σ2,marker='s',elinewidth=1,label=f'Fellow',color=cm.Oranges(v[fc]))
                    
                else:
                    errorbar(contrast,μ1,yerr=2*σ1,marker='o',elinewidth=1,color=cm.Blues(v[fc]))
                    errorbar(contrast,μ2,yerr=2*σ2,marker='s',elinewidth=1,color=cm.Oranges(v[fc]))
                
        else:
            s=Storage()
            for contrast_count,contrast in tqdm(enumerate(contrast_mat),total=len(contrast_mat)):

                params=all_params[count]
                count+=1
                R=Results(params.sfname)
                #R=RR[params.sfname]
                contrast=params.contrast
                μ1,μ2=R.μσ[0][0]
                σ1,σ2=R.μσ[1][0]

                s+=contrast,μ1,μ2,σ1,σ2

            contrast,μ1,μ2,σ1,σ2=s.arrays()

            errorbar(contrast,μ1,yerr=2*σ1,marker='o',elinewidth=1,color='black')
            errorbar(contrast,μ2,yerr=2*σ2,marker='s',elinewidth=1,color='gray')
            
                
        xlabel('Contrast')
        ylabel('Maximum Response')
        title(f'μc={mu_c} σc={sigma_c} blur={blur}')
        legend()                        
                    
    divider = make_axes_locatable(plt.gca())
    ax_cb = divider.new_horizontal(size="5%", pad=0.05)   
    ax_cb.grid(False)
    ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
    ax_cb2.grid(False)
    cb1 = mpl.colorbar.ColorbarBase(ax_cb, cmap=Blues2,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
    cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=Oranges2,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
    plt.gcf().add_axes(ax_cb)
    ax_cb.grid(True)
    ax_cb.set_yticklabels([])
    ax_cb2.grid(True)
    title(r'$f$')
    plt.gcf().add_axes(ax_cb2)
    title(r'$f$')

    figcount+=1
    
    if figcount==2:
        break
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]

# %% [markdown]
# ![image.png](attachment:18e60ee3-5e3e-45ff-bc30-6c7d1a13aebe.png)

# %%
count=0

v=np.flip(linspace(0.3,1,len(f_mat)))
figcount=0

for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    figure()
    for mask in mask_mat:
        if mask:
            for fc,f in tqdm(enumerate(f_mat),total=len(f_mat)):
                s=Storage()
                for contrast_count,contrast in tqdm(enumerate(contrast_mat),total=len(contrast_mat)):

                    params=all_params[count]
                    count+=1
                    R=Results(params.sfname)
                    #R=RR[params.sfname]
                    contrast=params.contrast
                    μ,σ=μσ(R.ODI[-1])

                    s+=contrast,μ,σ
                    
                contrast,μ,σ=s.arrays()

                
                errorbar(contrast,μ,yerr=2*σ,marker='o',elinewidth=1,color=cm.Blues(v[fc]))
                
        else:
            s=Storage()
            for contrast_count,contrast in tqdm(enumerate(contrast_mat),total=len(contrast_mat)):

                params=all_params[count]
                count+=1
                R=Results(params.sfname)
                #R=RR[params.sfname]
                contrast=params.contrast
                μ,σ=μσ(R.ODI[-1])

                s+=contrast,μ,σ

            contrast,μ,σ=s.arrays()

            errorbar(contrast,μ,yerr=2*σ,marker='o',elinewidth=1,color='black')

            
        ylim([-1,1])
        xl=xlim()
        plot(xl,[0,0],'k-',lw=2)
                
        xlabel('Contrast')
        ylabel(r'$\longleftarrow$ Weak Eye              Strong Eye $\longrightarrow$'+"\nODI")
        title(f'μc={mu_c} σc={sigma_c} blur={blur}')

                    

    divider = make_axes_locatable(plt.gca())
    ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
    ax_cb2.grid(False)
    cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=cm.Blues,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
    ax_cb2.grid(True)
    plt.gcf().add_axes(ax_cb2)
    title(r'$f$')



    figcount+=1
    
    if figcount==2:
        break
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# Text(0.5, 1.0, '$f$')

# %%
count=0

v=np.flip(linspace(0.3,1,len(f_mat)))
figcount=0

for mu_c,sigma_c in zip(mu_c_mat,sigma_c_mat):
    figure()
    for mask in mask_mat:
        if mask:
            for fc,f in tqdm(enumerate(f_mat),total=len(f_mat)):
                s=Storage()
                for contrast_count,contrast in tqdm(enumerate(contrast_mat),total=len(contrast_mat)):

                    params=all_params[count]
                    count+=1
                    R=Results(params.sfname)
                    #R=RR[params.sfname]
                    contrast=params.contrast
                    t=R.t/day
                    recovery_rate_μ,recovery_rate_σ=μσ((R.ODI[-1,:]-R.ODI[0,:])/(t[-1]-t[0]))  

                    s+=contrast,recovery_rate_μ,recovery_rate_σ
                    
                contrast,μ,σ=s.arrays()

                
                errorbar(contrast,-μ,yerr=2*σ,marker='o',elinewidth=1,color=cm.Blues(v[fc]))
                
        else:
            s=Storage()
            for contrast_count,contrast in tqdm(enumerate(contrast_mat),total=len(contrast_mat)):

                params=all_params[count]
                count+=1
                R=Results(params.sfname)
                #R=RR[params.sfname]
                contrast=params.contrast
                t=R.t/day
                recovery_rate_μ,recovery_rate_σ=μσ((R.ODI[-1,:]-R.ODI[0,:])/(t[-1]-t[0]))  

                s+=contrast,recovery_rate_μ,recovery_rate_σ

            contrast,μ,σ=s.arrays()

            errorbar(contrast,-μ,yerr=2*σ,marker='o',elinewidth=1,color='black')

            
        xlabel('Contrast')
        ylabel(r'$\longleftarrow$ Slower recovery     Faster Recovery $\longrightarrow$'+"\n[ODI shift/time]")
        title(f'μc={mu_c} σc={sigma_c} blur={blur}')

                    

    divider = make_axes_locatable(plt.gca())
    ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
    ax_cb2.grid(False)
    cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=cm.Blues,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
    ax_cb2.grid(True)
    plt.gcf().add_axes(ax_cb2)
    title(r'$f$')



    figcount+=1
    
    if figcount==2:
        break
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
mu_c,sigma_c=7.5,2

#[p for p in all_params if p.mu_c==mu_c and p.sigma_c==sigma_c]

# %%
count=0


figcount=0
mu_c,sigma_c=0,0
plot_params=[p for p in all_params if p.mu_c==mu_c and p.sigma_c==sigma_c]

fig1_results=[]
fig2_results=[]
fig3_results=[]
for mask in mask_mat:
    if mask:
        for fc,f in tqdm(enumerate(f_mat),total=len(f_mat)):
            s=Storage()
            s2=Storage()
            s3=Storage()
            for contrast_count,contrast in tqdm(enumerate(contrast_mat),total=len(contrast_mat)):

                params=plot_params[count]
                count+=1
                R=Results(params.sfname)
                #R=RR[params.sfname]
                contrast=params.contrast
                μ1,μ2=R.μσ[0][0]
                σ1,σ2=R.μσ[1][0]

                s+=contrast,μ1,μ2,σ1,σ2
                
                μ,σ=μσ(R.ODI[-1])
                s2+=contrast,μ,σ
                
                t=R.t/day
                recovery_rate_μ,recovery_rate_σ=μσ((R.ODI[-1,:]-R.ODI[0,:])/(t[-1]-t[0]))  
                s3+=contrast,recovery_rate_μ,recovery_rate_σ
                
                

            contrast,μ1,μ2,σ1,σ2=s.arrays()
            fig1_results.append( (contrast,μ1,μ2,σ1,σ2,fc,mask) )
            
            contrast,μ,σ=s2.arrays()
            fig2_results.append( (contrast,μ,σ,fc,mask) )
            
            contrast,μ,σ=s3.arrays()
            fig3_results.append( (contrast,μ,σ,fc,mask) )
            

    else:
        s=Storage()
        s2=Storage()
        s3=Storage()
        for contrast_count,contrast in tqdm(enumerate(contrast_mat),total=len(contrast_mat)):

            params=plot_params[count]
            count+=1
            R=Results(params.sfname)
            #R=RR[params.sfname]
            contrast=params.contrast
            μ1,μ2=R.μσ[0][0]
            σ1,σ2=R.μσ[1][0]

            s+=contrast,μ1,μ2,σ1,σ2

            
            μ,σ=μσ(R.ODI[-1])
            s2+=contrast,μ,σ
            
            t=R.t/day
            recovery_rate_μ,recovery_rate_σ=μσ((R.ODI[-1,:]-R.ODI[0,:])/(t[-1]-t[0]))  
            s3+=contrast,recovery_rate_μ,recovery_rate_σ
            
            
            
        contrast,μ1,μ2,σ1,σ2=s.arrays()
        fig1_results.append( (contrast,μ1,μ2,σ1,σ2,fc,mask) )

        contrast,μ,σ=s2.arrays()
        fig2_results.append( (contrast,μ,σ,fc,mask) )

        contrast,μ,σ=s3.arrays()
        fig3_results.append( (contrast,μ,σ,fc,mask) )
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
figure(figsize=(32,21))
v=np.flip(linspace(0.3,1,len(f_mat)))

subplot(2,2,1)

for contrast,μ1,μ2,σ1,σ2,fc,mask in fig1_results:
    if mask:
        if fc==1:
            errorbar(contrast,μ1,yerr=2*σ1,marker='o',elinewidth=1,label=f'Amblyopic',color=cm.Blues(v[fc]))
            errorbar(contrast,μ2,yerr=2*σ2,marker='s',elinewidth=1,label=f'Fellow',color=cm.Oranges(v[fc]))

        else:
            errorbar(contrast,μ1,yerr=2*σ1,marker='o',elinewidth=1,color=cm.Blues(v[fc]))
            errorbar(contrast,μ2,yerr=2*σ2,marker='s',elinewidth=1,color=cm.Oranges(v[fc]))
    else:
        errorbar(contrast,μ1,yerr=2*σ1,marker='o',elinewidth=1,color='black')
        errorbar(contrast,μ2,yerr=2*σ2,marker='s',elinewidth=1,color='gray')
        
xlabel('Contrast')
ylabel('Maximum Response')
title(f'μc={mu_c} σc={sigma_c} blur={blur}')
legend()                        
        
        
divider = make_axes_locatable(plt.gca())
ax_cb = divider.new_horizontal(size="5%", pad=0.05)   
ax_cb.grid(False)
ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
ax_cb2.grid(False)
cb1 = mpl.colorbar.ColorbarBase(ax_cb, cmap=Blues2,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=Oranges2,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
plt.gcf().add_axes(ax_cb)
ax_cb.grid(True)
ax_cb.set_yticklabels([])
ax_cb2.grid(True)
title(r'$\sigma_f$') 
plt.gcf().add_axes(ax_cb2)
title(r'$\sigma_f$') 

subplot(2,2,2)

for contrast,μ,σ,fc,mask in fig2_results:
    if mask:
        errorbar(contrast,μ,yerr=2*σ,marker='o',elinewidth=1,color=cm.Blues(v[fc]))
    else:
        errorbar(contrast,μ,yerr=2*σ,marker='o',elinewidth=1,color='black')
        
    
            
ylim([-1,1])
xl=xlim()
plot(xl,[0,0],'k-',lw=2)

xlabel('Contrast')
ylabel(r'$\longleftarrow$ Amblyopic Eye              Fellow Eye $\longrightarrow$'+"\nODI")
title(f'μc={mu_c} σc={sigma_c} blur={blur}')

divider = make_axes_locatable(plt.gca())
ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
ax_cb2.grid(False)
cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=cm.Blues,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
ax_cb2.grid(True)
plt.gcf().add_axes(ax_cb2)
title(r'$\sigma_f$') 

ax=subplot(2,2,3)
pos=ax.get_position().bounds
ax.set_position([pos[0]+.2,pos[1],pos[2],pos[3]])

for contrast,μ,σ,fc,mask in fig2_results:
    if mask:
        errorbar(contrast,-μ,yerr=2*σ,marker='o',elinewidth=1,color=cm.Blues(v[fc]))
    else:
        errorbar(contrast,-μ,yerr=2*σ,marker='o',elinewidth=1,color='black')
        
    
            
ylim([-1,1])
xl=xlim()
plot(xl,[0,0],'k-',lw=2)

xlabel('Contrast')
ylabel(r'$\longleftarrow$ Slower recovery     Faster Recovery $\longrightarrow$'+"\n[ODI shift/time]")
title(f'μc={mu_c} σc={sigma_c} blur={blur}')

divider = make_axes_locatable(plt.gca())
ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
ax_cb2.grid(False)
cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=cm.Blues,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
ax_cb2.grid(True)
plt.gcf().add_axes(ax_cb2)
title(r'$\sigma_f$') 


plt.text(.1, 0.9, "A", transform=plt.gcf().transFigure,
    fontsize=26, fontweight='bold', va='top')

plt.text(.5, 0.9, "B", transform=plt.gcf().transFigure,
    fontsize=26, fontweight='bold', va='top')


plt.text(.23, 0.46, "C", transform=plt.gcf().transFigure,
    fontsize=26, fontweight='bold', va='top')

savefig('fig-mask-response-ODI-contrast-mu0-sigma0.png')
# Out:
# Manuscript/resources/fig-mask-response-ODI-contrast-mu0-sigma0.png
# Manuscript/resources/fig-mask-response-ODI-contrast-mu0-sigma0.svg

# %%
count=0


figcount=0
mu_c,sigma_c=7.5,2
plot_params=[p for p in all_params if p.mu_c==mu_c and p.sigma_c==sigma_c]

fig1_results=[]
fig2_results=[]
fig3_results=[]
for mask in mask_mat:
    if mask:
        for fc,f in tqdm(enumerate(f_mat),total=len(f_mat)):
            s=Storage()
            s2=Storage()
            s3=Storage()
            for contrast_count,contrast in tqdm(enumerate(contrast_mat),total=len(contrast_mat)):

                params=plot_params[count]
                count+=1
                R=Results(params.sfname)
                #R=RR[params.sfname]
                contrast=params.contrast
                μ1,μ2=R.μσ[0][0]
                σ1,σ2=R.μσ[1][0]

                s+=contrast,μ1,μ2,σ1,σ2
                
                μ,σ=μσ(R.ODI[-1])
                s2+=contrast,μ,σ
                
                t=R.t/day
                recovery_rate_μ,recovery_rate_σ=μσ((R.ODI[-1,:]-R.ODI[0,:])/(t[-1]-t[0]))  
                s3+=contrast,recovery_rate_μ,recovery_rate_σ
                
                

            contrast,μ1,μ2,σ1,σ2=s.arrays()
            fig1_results.append( (contrast,μ1,μ2,σ1,σ2,fc,mask) )
            
            contrast,μ,σ=s2.arrays()
            fig2_results.append( (contrast,μ,σ,fc,mask) )
            
            contrast,μ,σ=s3.arrays()
            fig3_results.append( (contrast,μ,σ,fc,mask) )
            

    else:
        s=Storage()
        s2=Storage()
        s3=Storage()
        for contrast_count,contrast in tqdm(enumerate(contrast_mat),total=len(contrast_mat)):

            params=plot_params[count]
            count+=1
            R=Results(params.sfname)
            #R=RR[params.sfname]
            contrast=params.contrast
            μ1,μ2=R.μσ[0][0]
            σ1,σ2=R.μσ[1][0]

            s+=contrast,μ1,μ2,σ1,σ2

            
            μ,σ=μσ(R.ODI[-1])
            s2+=contrast,μ,σ
            
            t=R.t/day
            recovery_rate_μ,recovery_rate_σ=μσ((R.ODI[-1,:]-R.ODI[0,:])/(t[-1]-t[0]))  
            s3+=contrast,recovery_rate_μ,recovery_rate_σ
            
            
            
        contrast,μ1,μ2,σ1,σ2=s.arrays()
        fig1_results.append( (contrast,μ1,μ2,σ1,σ2,fc,mask) )

        contrast,μ,σ=s2.arrays()
        fig2_results.append( (contrast,μ,σ,fc,mask) )

        contrast,μ,σ=s3.arrays()
        fig3_results.append( (contrast,μ,σ,fc,mask) )
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
figure(figsize=(32,21))
v=np.flip(linspace(0.3,1,len(f_mat)))

subplot(2,2,1)

for contrast,μ1,μ2,σ1,σ2,fc,mask in fig1_results:
    if mask:
        if fc==1:
            errorbar(contrast,μ1,yerr=2*σ1,marker='o',elinewidth=1,label=f'Amblyopic',color=cm.Blues(v[fc]))
            errorbar(contrast,μ2,yerr=2*σ2,marker='s',elinewidth=1,label=f'Fellow',color=cm.Oranges(v[fc]))

        else:
            errorbar(contrast,μ1,yerr=2*σ1,marker='o',elinewidth=1,color=cm.Blues(v[fc]))
            errorbar(contrast,μ2,yerr=2*σ2,marker='s',elinewidth=1,color=cm.Oranges(v[fc]))
    else:
        errorbar(contrast,μ1,yerr=2*σ1,marker='o',elinewidth=1,color='black')
        errorbar(contrast,μ2,yerr=2*σ2,marker='s',elinewidth=1,color='gray')
        
xlabel('Contrast')
ylabel('Maximum Response')
title(f'μc={mu_c} σc={sigma_c} blur={blur}')
legend()                        
        
        
divider = make_axes_locatable(plt.gca())
ax_cb = divider.new_horizontal(size="5%", pad=0.05)   
ax_cb.grid(False)
ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
ax_cb2.grid(False)
cb1 = mpl.colorbar.ColorbarBase(ax_cb, cmap=Blues2,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=Oranges2,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
plt.gcf().add_axes(ax_cb)
ax_cb.grid(True)
ax_cb.set_yticklabels([])
ax_cb2.grid(True)
title(r'$\sigma_f$') 
plt.gcf().add_axes(ax_cb2)
title(r'$\sigma_f$') 

subplot(2,2,2)

for contrast,μ,σ,fc,mask in fig2_results:
    if mask:
        errorbar(contrast,μ,yerr=2*σ,marker='o',elinewidth=1,color=cm.Blues(v[fc]))
    else:
        errorbar(contrast,μ,yerr=2*σ,marker='o',elinewidth=1,color='black')
        
    
            
ylim([-1,1])
xl=xlim()
plot(xl,[0,0],'k-',lw=2)

xlabel('Contrast')
ylabel(r'$\longleftarrow$ Amblyopic Eye              Fellow Eye $\longrightarrow$'+"\nODI")
title(f'μc={mu_c} σc={sigma_c} blur={blur}')

divider = make_axes_locatable(plt.gca())
ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
ax_cb2.grid(False)
cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=cm.Blues,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
ax_cb2.grid(True)
plt.gcf().add_axes(ax_cb2)
title(r'$\sigma_f$') 

ax=subplot(2,2,3)
pos=ax.get_position().bounds
ax.set_position([pos[0]+.2,pos[1],pos[2],pos[3]])

for contrast,μ,σ,fc,mask in fig2_results:
    if mask:
        errorbar(contrast,-μ,yerr=2*σ,marker='o',elinewidth=1,color=cm.Blues(v[fc]))
    else:
        errorbar(contrast,-μ,yerr=2*σ,marker='o',elinewidth=1,color='black')
        
    
            
ylim([-1,1])
xl=xlim()
plot(xl,[0,0],'k-',lw=2)

xlabel('Contrast')
ylabel(r'$\longleftarrow$ Slower recovery     Faster Recovery $\longrightarrow$'+"\n[ODI shift/time]")
title(f'μc={mu_c} σc={sigma_c} blur={blur}')

divider = make_axes_locatable(plt.gca())
ax_cb2 = divider.new_horizontal(size="5%", pad=0.05)    
ax_cb2.grid(False)
cb2 = mpl.colorbar.ColorbarBase(ax_cb2, cmap=cm.Blues,norm=mpl.colors.Normalize(vmin=f_mat[0], vmax=f_mat[-1]),orientation='vertical')
ax_cb2.grid(True)
plt.gcf().add_axes(ax_cb2)
title(r'$\sigma_f$') 


plt.text(.1, 0.9, "A", transform=plt.gcf().transFigure,
    fontsize=26, fontweight='bold', va='top')

plt.text(.5, 0.9, "B", transform=plt.gcf().transFigure,
    fontsize=26, fontweight='bold', va='top')


plt.text(.23, 0.46, "C", transform=plt.gcf().transFigure,
    fontsize=26, fontweight='bold', va='top')

savefig('fig-mask-response-ODI-contrast-mu75-sigma2.png')
# Out:
# Manuscript/resources/fig-mask-response-ODI-contrast-mu75-sigma2.png
# Manuscript/resources/fig-mask-response-ODI-contrast-mu75-sigma2.svg
